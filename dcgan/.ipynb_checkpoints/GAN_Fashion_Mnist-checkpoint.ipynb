# %%
import tensorflow as tf

from tensorflow.keras.layers import *
from tensorflow.keras.models import Model

class DCGAN(object):
    def __init__(self, input_shape=(28,28,1), latent_dim=100):
        self.latent_dim = latent_dim
        self.input_shape = input_shape
        
    def build_generator(self):
        inputs = Input(shape=(self.latent_dim,))
        
        x = Dense(7 * 7 * 16, use_bias=False)(inputs)
        x = Reshape(target_shape=(7, 7, 16))(x)
        
        ### Now shape = 14 x 14 x 32 ###
        x = Conv2DTranspose(32, kernel_size=(3,3), strides=2, padding='same', use_bias=False)(x)
        x = BatchNormalization()(x)
        x = LeakyReLU()(x) 
        
        ### Now shape = 28 x 28 x 64 ###
        x = Conv2DTranspose(64, kernel_size=(3,3), strides=2, padding='same', use_bias=False)(x)
        x = BatchNormalization()(x)
        x = LeakyReLU()(x)
        
        ### Now shape = 28 x 28 x 1 ###
        x = Conv2DTranspose(1, kernel_size=(3,3), strides=1, padding='same', use_bias=False)(x)
        x = Activation("tanh")(x)
        
        generator = Model(inputs=inputs, outputs=x, name='generator')
        return generator
    
    def build_discriminator(self):
        inputs = Input(shape=self.input_shape)
        
        ### Now shape = 64 x 14 x 14 ###
        x = Conv2D(64, kernel_size=(3,3), strides=2, padding='same')(inputs)
        x = LeakyReLU()(x)
        x = Dropout(0.3)(x)
        
        ### Now shape = 32 x 7 x 7 ###
        x = Conv2D(32, kernel_size=(3,3), strides=2, padding='same')(x)
        x = LeakyReLU()(x)
        x = Dropout(0.3)(x)
        
        x = Flatten()(x)
        x = Dense(1)(x)
        
        discriminator = Model(inputs=inputs, outputs=x, name='discriminator')
        return discriminator

# %%
### Training (On hand digit mnist ) ###
import os
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from scipy.spatial.distance import jensenshannon
from tensorflow.keras import backend as K
from tensorflow.keras import optimizers
from tensorflow.keras.datasets import fashion_mnist, mnist
from tensorflow.keras.losses import BinaryCrossentropy

latent_dim = 100
epochs     = 250
batch_size = 64

g = DCGAN().build_generator()
d = DCGAN().build_discriminator()

if(os.path.exists('weights/g.weights.hdf5')):
    print('[*] Found weights file for generator ...')
    g.load_weights('weights/g.weights.hdf5')

if(os.path.exists('weights/d.weights.hdf5')):
    print('[*] Found weights file for discriminator ...')
    d.load_weights('weights/d.weights.hdf5')
    
g_opt = optimizers.Adam(1e-4)
d_opt = optimizers.Adam(1e-4)

print(g.summary())
print(d.summary())
bce = BinaryCrossentropy(from_logits=True)
def generator_loss(fake_output):
    labels = tf.ones(shape=(K.shape(fake_output)[0], 1))
    loss = bce(labels, fake_output)
    # loss = K.mean(loss)

    return loss

def discriminator_loss(real_output, fake_output):
    zeros = tf.zeros(shape=(K.shape(real_output)[0], 1))
    ones  = tf.ones(shape=(K.shape(real_output)[0], 1))
    
    real_loss = bce(ones, real_output)
    fake_loss = bce(zeros, fake_output)
    loss = real_loss + fake_loss
    # loss = K.mean(loss)
    
    return loss

def sigmoid(x):
    return 1 / (1 + np.exp(x))

@tf.function
def train_step(images):
    ### Calculating generator loss ###
    with tf.GradientTape() as g_tape, tf.GradientTape() as d_tape:
        noise = K.random_normal(shape=(K.shape(images)[0], latent_dim))
        generated_images = g(noise, training=True)

        fake_output = d(generated_images, training=True)
        real_output = d(images, training=True)
        
        g_loss = generator_loss(fake_output)
        d_loss = discriminator_loss(real_output, fake_output)
        
    g_gradients = g_tape.gradient(g_loss, g.trainable_variables)
    d_gradients = d_tape.gradient(d_loss, d.trainable_variables)
        
    g_opt.apply_gradients(zip(g_gradients, g.trainable_variables))
    d_opt.apply_gradients(zip(d_gradients, d.trainable_variables))
    
    return fake_output, real_output, g_loss, d_loss
    
(X_train, _), (X_test, _) = mnist.load_data()

X_train = (X_train - 127.5) / 127.5
X_train = X_train[:15000]
num_batches = X_train.shape[0] // batch_size

print('[INFO] Starting training...')
js_values = []
for i in range(epochs):
    ### Loop thru the batchs ###
    g_losses = []
    d_losses = []
    for j in range(num_batches):
        batch = X_train[j*batch_size:(j+1)*batch_size]
        fake, real, g_loss, d_loss = train_step(batch)
        
        js = jensenshannon(sigmoid(real), sigmoid(fake))
        g_losses.append(g_loss)
        d_losses.append(d_loss)
        js_values.append(js[0])
    
    if(i % 15 == 0):
        g.save_weights('weights/g.weights.hdf5')
        d.save_weights('weights/d.weights.hdf5')
        
    print('Epochs number {} | generator loss = {}, discriminator loss = {}'.format(i+1, np.array(g_losses).mean(), np.array(d_losses).mean()))    
    
### Testing ...  ###
generator = DCGAN().build_generator()
generator.load_weights('weights/g.weights.hdf5')

latent_dim = 100
num_images = 100
grid_size = 10
noise = K.random_normal(shape=(num_images, latent_dim))
predictions = generator.predict(noise)
predictions = (predictions * 127.5 ) + 127.5
predictions = predictions.astype('uint8')

fig1, ax1 = plt.subplots(grid_size, grid_size, figsize=(30,30))
for i in range(num_images):
    row = i // grid_size
    col = i % grid_size
    
    ax1[row][col].imshow(predictions[i])

fig2, ax2 = plt.subplots(figsize=(15,3))
ax2.plot(js_values)
ax2.set_title('JS-Divergence between D(fake) and D(real)')
ax2.set_xlabel('Batch Number')
ax2.set_ylabel('JS-Divergence')
plt.show()
# Out:
# Model: "generator"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_27 (InputLayer)        [(None, 100)]             0
# _________________________________________________________________
# dense_26 (Dense)             (None, 784)               78400
# _________________________________________________________________
# reshape_16 (Reshape)         (None, 7, 7, 16)          0
# _________________________________________________________________
# conv2d_transpose_48 (Conv2DT (None, 14, 14, 32)        4608
# _________________________________________________________________
# batch_normalization_32 (Batc (None, 14, 14, 32)        128
# _________________________________________________________________
# leaky_re_lu_52 (LeakyReLU)   (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_transpose_49 (Conv2DT (None, 28, 28, 64)        18432
# _________________________________________________________________
# batch_normalization_33 (Batc (None, 28, 28, 64)        256
# _________________________________________________________________
# leaky_re_lu_53 (LeakyReLU)   (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_transpose_50 (Conv2DT (None, 28, 28, 1)         576
# _________________________________________________________________
# activation_16 (Activation)   (None, 28, 28, 1)         0
# =================================================================
# Total params: 102,400
# Trainable params: 102,208
# Non-trainable params: 192
# _________________________________________________________________
# None
# Model: "discriminator"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_28 (InputLayer)        [(None, 28, 28, 1)]       0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 14, 14, 64)        640
# _________________________________________________________________
# leaky_re_lu_54 (LeakyReLU)   (None, 14, 14, 64)        0
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 7, 7, 32)          18464
# _________________________________________________________________
# leaky_re_lu_55 (LeakyReLU)   (None, 7, 7, 32)          0
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 7, 7, 32)          0
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 1568)              0
# _________________________________________________________________
# dense_27 (Dense)             (None, 1)                 1569
# =================================================================
# Total params: 20,673
# Trainable params: 20,673
# Non-trainable params: 0
# _________________________________________________________________
# None
# [INFO] Starting training...
# Epochs number 1 | generator loss = 0.7950950860977173, discriminator loss = 1.044512152671814
# Epochs number 2 | generator loss = 1.1262266635894775, discriminator loss = 0.8750178813934326
# Epochs number 3 | generator loss = 0.7391683459281921, discriminator loss = 1.4152764081954956
# Epochs number 4 | generator loss = 0.7368860244750977, discriminator loss = 1.3776271343231201
# Epochs number 5 | generator loss = 0.7198204398155212, discriminator loss = 1.3743510246276855
# Epochs number 6 | generator loss = 0.7280903458595276, discriminator loss = 1.3610482215881348
# Epochs number 7 | generator loss = 0.7292464971542358, discriminator loss = 1.3583455085754395
# Epochs number 8 | generator loss = 0.7286349534988403, discriminator loss = 1.3652127981185913
# Epochs number 9 | generator loss = 0.7293145656585693, discriminator loss = 1.368011474609375
# Epochs number 10 | generator loss = 0.7419394254684448, discriminator loss = 1.3529964685440063
# Epochs number 11 | generator loss = 0.7339147329330444, discriminator loss = 1.3564784526824951
# Epochs number 12 | generator loss = 0.726719856262207, discriminator loss = 1.3541979789733887
# Epochs number 13 | generator loss = 0.7396953701972961, discriminator loss = 1.3535709381103516
# Epochs number 14 | generator loss = 0.7342484593391418, discriminator loss = 1.3477113246917725
# Epochs number 15 | generator loss = 0.74864661693573, discriminator loss = 1.3338922262191772
# Epochs number 16 | generator loss = 0.7396078109741211, discriminator loss = 1.3426685333251953
# Epochs number 17 | generator loss = 0.7401239275932312, discriminator loss = 1.3507522344589233
# Epochs number 18 | generator loss = 0.752251386642456, discriminator loss = 1.3239240646362305
# Epochs number 19 | generator loss = 0.7623862028121948, discriminator loss = 1.3185229301452637
# Epochs number 20 | generator loss = 0.7657318115234375, discriminator loss = 1.3237252235412598
# Epochs number 21 | generator loss = 0.7770935297012329, discriminator loss = 1.2946470975875854
# Epochs number 22 | generator loss = 0.766282320022583, discriminator loss = 1.296058177947998
# Epochs number 23 | generator loss = 0.7992264032363892, discriminator loss = 1.282455325126648
# Epochs number 24 | generator loss = 0.807938814163208, discriminator loss = 1.281296968460083
# Epochs number 25 | generator loss = 0.7956417798995972, discriminator loss = 1.2682737112045288
# Epochs number 26 | generator loss = 0.8445748686790466, discriminator loss = 1.225869059562683
# Epochs number 27 | generator loss = 0.8708731532096863, discriminator loss = 1.2152875661849976
# Epochs number 28 | generator loss = 0.884611964225769, discriminator loss = 1.1933141946792603
# Epochs number 29 | generator loss = 0.9166212677955627, discriminator loss = 1.1732109785079956
# Epochs number 30 | generator loss = 0.9023004770278931, discriminator loss = 1.2083004713058472
# Epochs number 31 | generator loss = 0.9092981219291687, discriminator loss = 1.1572461128234863
# Epochs number 32 | generator loss = 0.9352601766586304, discriminator loss = 1.1473605632781982
# Epochs number 33 | generator loss = 0.9251469373703003, discriminator loss = 1.1678886413574219
# Epochs number 34 | generator loss = 0.9448968768119812, discriminator loss = 1.1351509094238281
# Epochs number 35 | generator loss = 0.9861101508140564, discriminator loss = 1.1140127182006836
# Epochs number 36 | generator loss = 0.9857832193374634, discriminator loss = 1.1309468746185303
# Epochs number 37 | generator loss = 1.0210003852844238, discriminator loss = 1.0912340879440308
# Epochs number 38 | generator loss = 1.030726432800293, discriminator loss = 1.0677869319915771
# Epochs number 39 | generator loss = 1.0545365810394287, discriminator loss = 1.073999285697937
# Epochs number 40 | generator loss = 1.0503392219543457, discriminator loss = 1.0819511413574219
# Epochs number 41 | generator loss = 1.049885630607605, discriminator loss = 1.110809326171875
# Epochs number 42 | generator loss = 1.0619713068008423, discriminator loss = 1.0820914506912231
# Epochs number 43 | generator loss = 1.070677399635315, discriminator loss = 1.0872257947921753
# Epochs number 44 | generator loss = 1.0912235975265503, discriminator loss = 1.0944268703460693
# Epochs number 45 | generator loss = 1.083743929862976, discriminator loss = 1.0771654844284058
# Epochs number 46 | generator loss = 1.069115400314331, discriminator loss = 1.0989069938659668
# Epochs number 47 | generator loss = 1.0620696544647217, discriminator loss = 1.109640121459961
# Epochs number 48 | generator loss = 1.0539097785949707, discriminator loss = 1.1128413677215576
# Epochs number 49 | generator loss = 1.0485906600952148, discriminator loss = 1.1161893606185913
# Epochs number 50 | generator loss = 1.0496665239334106, discriminator loss = 1.1304030418395996
# Epochs number 51 | generator loss = 1.0414221286773682, discriminator loss = 1.1349904537200928
# Epochs number 52 | generator loss = 1.0379092693328857, discriminator loss = 1.1408655643463135
# Epochs number 53 | generator loss = 1.0342633724212646, discriminator loss = 1.142274022102356
# Epochs number 54 | generator loss = 1.0269967317581177, discriminator loss = 1.1487056016921997
# Epochs number 55 | generator loss = 1.0253194570541382, discriminator loss = 1.1520971059799194
# Epochs number 56 | generator loss = 1.0190221071243286, discriminator loss = 1.1568454504013062
# Epochs number 57 | generator loss = 1.0175914764404297, discriminator loss = 1.16444730758667
# Epochs number 58 | generator loss = 1.0127660036087036, discriminator loss = 1.1638883352279663
# Epochs number 59 | generator loss = 1.0051339864730835, discriminator loss = 1.169995665550232
# Epochs number 60 | generator loss = 0.9980376362800598, discriminator loss = 1.1782050132751465
# Epochs number 61 | generator loss = 0.9949455857276917, discriminator loss = 1.1746160984039307
# Epochs number 62 | generator loss = 1.0017728805541992, discriminator loss = 1.175413727760315
# Epochs number 63 | generator loss = 0.9887280464172363, discriminator loss = 1.1966065168380737
# Epochs number 64 | generator loss = 0.9820579886436462, discriminator loss = 1.1923693418502808
# Epochs number 65 | generator loss = 0.981802761554718, discriminator loss = 1.191731333732605
# Epochs number 66 | generator loss = 0.9691177010536194, discriminator loss = 1.2050679922103882
# Epochs number 67 | generator loss = 0.9541515111923218, discriminator loss = 1.2228314876556396
# Epochs number 68 | generator loss = 0.9577701091766357, discriminator loss = 1.2114980220794678
# Epochs number 69 | generator loss = 0.9488927125930786, discriminator loss = 1.226834774017334
# Epochs number 70 | generator loss = 0.9368306398391724, discriminator loss = 1.232776403427124
# Epochs number 71 | generator loss = 0.9388006329536438, discriminator loss = 1.2246062755584717
# Epochs number 72 | generator loss = 0.9230973124504089, discriminator loss = 1.2476303577423096
# Epochs number 73 | generator loss = 0.9232232570648193, discriminator loss = 1.2354775667190552
# Epochs number 74 | generator loss = 0.916115939617157, discriminator loss = 1.246351957321167
# Epochs number 75 | generator loss = 0.9164548516273499, discriminator loss = 1.2392605543136597
# Epochs number 76 | generator loss = 0.8991460800170898, discriminator loss = 1.2604548931121826
# Epochs number 77 | generator loss = 0.9004255533218384, discriminator loss = 1.2527204751968384
# Epochs number 78 | generator loss = 0.8977835774421692, discriminator loss = 1.260637640953064
# Epochs number 79 | generator loss = 0.8924095630645752, discriminator loss = 1.2594751119613647
# Epochs number 80 | generator loss = 0.8912235498428345, discriminator loss = 1.259366750717163
# Epochs number 81 | generator loss = 0.8899973630905151, discriminator loss = 1.2641613483428955
# Epochs number 82 | generator loss = 0.8966131210327148, discriminator loss = 1.2507803440093994
# Epochs number 83 | generator loss = 0.8807451725006104, discriminator loss = 1.2710226774215698
# Epochs number 84 | generator loss = 0.881186842918396, discriminator loss = 1.2675700187683105
# Epochs number 85 | generator loss = 0.8798785209655762, discriminator loss = 1.2628751993179321
# Epochs number 86 | generator loss = 0.8768350481987, discriminator loss = 1.2692201137542725
# Epochs number 87 | generator loss = 0.8760679364204407, discriminator loss = 1.2677375078201294
# Epochs number 88 | generator loss = 0.8708332777023315, discriminator loss = 1.2712970972061157
# Epochs number 89 | generator loss = 0.8685306906700134, discriminator loss = 1.273604393005371
# Epochs number 90 | generator loss = 0.8749799132347107, discriminator loss = 1.265214443206787
# Epochs number 91 | generator loss = 0.8672953844070435, discriminator loss = 1.2757060527801514
# Epochs number 92 | generator loss = 0.8594186902046204, discriminator loss = 1.2801164388656616
# Epochs number 93 | generator loss = 0.8607140183448792, discriminator loss = 1.2793071269989014
# Epochs number 94 | generator loss = 0.8629177808761597, discriminator loss = 1.275543451309204
# Epochs number 95 | generator loss = 0.8712872862815857, discriminator loss = 1.2690585851669312
# Epochs number 96 | generator loss = 0.8649953007698059, discriminator loss = 1.2762980461120605
# Epochs number 97 | generator loss = 0.8561190962791443, discriminator loss = 1.2848109006881714
# Epochs number 98 | generator loss = 0.8564079999923706, discriminator loss = 1.280896782875061
# Epochs number 99 | generator loss = 0.858040452003479, discriminator loss = 1.2768299579620361
# Epochs number 100 | generator loss = 0.8539063334465027, discriminator loss = 1.2820568084716797
# Epochs number 101 | generator loss = 0.8481823801994324, discriminator loss = 1.286206841468811
# Epochs number 102 | generator loss = 0.8557124733924866, discriminator loss = 1.2799748182296753
# Epochs number 103 | generator loss = 0.8488812446594238, discriminator loss = 1.2863295078277588
# Epochs number 104 | generator loss = 0.8498031497001648, discriminator loss = 1.28957998752594
# Epochs number 105 | generator loss = 0.8451544642448425, discriminator loss = 1.289327621459961
# Epochs number 106 | generator loss = 0.8431650996208191, discriminator loss = 1.289044737815857
# Epochs number 107 | generator loss = 0.8395651578903198, discriminator loss = 1.2937551736831665
# Epochs number 108 | generator loss = 0.8376802802085876, discriminator loss = 1.2941359281539917
# Epochs number 109 | generator loss = 0.8385058045387268, discriminator loss = 1.2921037673950195
# Epochs number 110 | generator loss = 0.8361301422119141, discriminator loss = 1.2986392974853516
# Epochs number 111 | generator loss = 0.8355123400688171, discriminator loss = 1.296215295791626
# Epochs number 112 | generator loss = 0.8396756649017334, discriminator loss = 1.2923612594604492
# Epochs number 113 | generator loss = 0.8317745923995972, discriminator loss = 1.2973343133926392
# Epochs number 114 | generator loss = 0.8341869115829468, discriminator loss = 1.2958084344863892
# Epochs number 115 | generator loss = 0.8354843258857727, discriminator loss = 1.2910456657409668
# Epochs number 116 | generator loss = 0.8297823667526245, discriminator loss = 1.3022812604904175
# Epochs number 117 | generator loss = 0.8301334381103516, discriminator loss = 1.2954943180084229
# Epochs number 118 | generator loss = 0.8310009837150574, discriminator loss = 1.304046392440796
# Epochs number 119 | generator loss = 0.829071044921875, discriminator loss = 1.291913390159607
# Epochs number 120 | generator loss = 0.8425995111465454, discriminator loss = 1.3046876192092896
# Epochs number 121 | generator loss = 0.8268454670906067, discriminator loss = 1.30282461643219
# Epochs number 122 | generator loss = 0.8263679146766663, discriminator loss = 1.3004481792449951
# Epochs number 123 | generator loss = 0.8344414830207825, discriminator loss = 1.3044837713241577
# Epochs number 124 | generator loss = 0.8285951614379883, discriminator loss = 1.3010673522949219
# Epochs number 125 | generator loss = 0.8199824094772339, discriminator loss = 1.3052829504013062
# Epochs number 126 | generator loss = 0.8219316005706787, discriminator loss = 1.2974109649658203
# Epochs number 127 | generator loss = 0.8280378580093384, discriminator loss = 1.3015530109405518
# Epochs number 128 | generator loss = 0.827942430973053, discriminator loss = 1.3079408407211304
# Epochs number 129 | generator loss = 0.8199302554130554, discriminator loss = 1.3028825521469116
# Epochs number 130 | generator loss = 0.8209870457649231, discriminator loss = 1.3019764423370361
# Epochs number 131 | generator loss = 0.8400416970252991, discriminator loss = 1.2992571592330933
# Epochs number 132 | generator loss = 0.8196184039115906, discriminator loss = 1.3120322227478027
# Epochs number 133 | generator loss = 0.8174607753753662, discriminator loss = 1.3062318563461304
# Epochs number 134 | generator loss = 0.8167452812194824, discriminator loss = 1.3068779706954956
# Epochs number 135 | generator loss = 0.8216042518615723, discriminator loss = 1.309783697128296
# Epochs number 136 | generator loss = 0.8174787759780884, discriminator loss = 1.3035129308700562
# Epochs number 137 | generator loss = 0.8151328563690186, discriminator loss = 1.309922218322754
# Epochs number 138 | generator loss = 0.817234992980957, discriminator loss = 1.3085988759994507
# Epochs number 139 | generator loss = 0.8109734654426575, discriminator loss = 1.3058103322982788
# Epochs number 140 | generator loss = 0.8252599835395813, discriminator loss = 1.3045200109481812
# Epochs number 141 | generator loss = 0.8276760578155518, discriminator loss = 1.3058103322982788
# Epochs number 142 | generator loss = 0.818384051322937, discriminator loss = 1.299420714378357
# Epochs number 143 | generator loss = 0.8175814151763916, discriminator loss = 1.3017470836639404
# Epochs number 144 | generator loss = 0.8347054719924927, discriminator loss = 1.3028795719146729
# Epochs number 145 | generator loss = 0.8282246589660645, discriminator loss = 1.3006670475006104
# Epochs number 146 | generator loss = 0.8230111002922058, discriminator loss = 1.3061531782150269
# Epochs number 147 | generator loss = 0.8132644891738892, discriminator loss = 1.3120208978652954
# Epochs number 148 | generator loss = 0.8207125663757324, discriminator loss = 1.3023110628128052
# Epochs number 149 | generator loss = 0.8241755962371826, discriminator loss = 1.304456114768982
# Epochs number 150 | generator loss = 0.8213919401168823, discriminator loss = 1.3026806116104126
# Epochs number 151 | generator loss = 0.8202991485595703, discriminator loss = 1.3043838739395142
# Epochs number 152 | generator loss = 0.8264963626861572, discriminator loss = 1.3084012269973755
# Epochs number 153 | generator loss = 0.8307185173034668, discriminator loss = 1.3006490468978882
# Epochs number 154 | generator loss = 0.8273093104362488, discriminator loss = 1.3072760105133057
# Epochs number 155 | generator loss = 0.8172061443328857, discriminator loss = 1.3115917444229126
# Epochs number 156 | generator loss = 0.8280222415924072, discriminator loss = 1.301590919494629
# Epochs number 157 | generator loss = 0.8220373392105103, discriminator loss = 1.3126453161239624
# Epochs number 158 | generator loss = 0.8195107579231262, discriminator loss = 1.304662823677063
# Epochs number 159 | generator loss = 0.8165048360824585, discriminator loss = 1.3082534074783325
# Epochs number 160 | generator loss = 0.8244914412498474, discriminator loss = 1.3061490058898926
# Epochs number 161 | generator loss = 0.8162916302680969, discriminator loss = 1.3084837198257446
# Epochs number 162 | generator loss = 0.818278431892395, discriminator loss = 1.3047863245010376
# Epochs number 163 | generator loss = 0.8194159269332886, discriminator loss = 1.3046329021453857
# Epochs number 164 | generator loss = 0.8173081874847412, discriminator loss = 1.3058379888534546
# Epochs number 165 | generator loss = 0.8204498887062073, discriminator loss = 1.3066258430480957
# Epochs number 166 | generator loss = 0.8101484775543213, discriminator loss = 1.3150248527526855
# Epochs number 167 | generator loss = 0.8081433176994324, discriminator loss = 1.313888430595398
# Epochs number 168 | generator loss = 0.8247225284576416, discriminator loss = 1.3061394691467285
# Epochs number 169 | generator loss = 0.8141276240348816, discriminator loss = 1.314163088798523
# Epochs number 170 | generator loss = 0.8094936013221741, discriminator loss = 1.312080979347229
# Epochs number 171 | generator loss = 0.8096429705619812, discriminator loss = 1.3116648197174072
# Epochs number 172 | generator loss = 0.8173018097877502, discriminator loss = 1.3055391311645508
# Epochs number 173 | generator loss = 0.8201951384544373, discriminator loss = 1.3100810050964355
# Epochs number 174 | generator loss = 0.8140642046928406, discriminator loss = 1.305919885635376
# Epochs number 175 | generator loss = 0.8070108890533447, discriminator loss = 1.3162813186645508
# Epochs number 176 | generator loss = 0.8213984966278076, discriminator loss = 1.3088864088058472
# Epochs number 177 | generator loss = 0.8134626150131226, discriminator loss = 1.3107870817184448
# Epochs number 178 | generator loss = 0.8094289898872375, discriminator loss = 1.3114973306655884
# Epochs number 179 | generator loss = 0.8124591112136841, discriminator loss = 1.312741994857788
# Epochs number 180 | generator loss = 0.8178975582122803, discriminator loss = 1.3150129318237305
# Epochs number 181 | generator loss = 0.8083716630935669, discriminator loss = 1.3151850700378418
# Epochs number 182 | generator loss = 0.811928391456604, discriminator loss = 1.3058346509933472
# Epochs number 183 | generator loss = 0.8041507005691528, discriminator loss = 1.320220708847046
# Epochs number 184 | generator loss = 0.8208518028259277, discriminator loss = 1.3077285289764404
# Epochs number 185 | generator loss = 0.8055795431137085, discriminator loss = 1.31338369846344
# Epochs number 186 | generator loss = 0.8043469786643982, discriminator loss = 1.312903642654419
# Epochs number 187 | generator loss = 0.8209697008132935, discriminator loss = 1.3082938194274902
# Epochs number 188 | generator loss = 0.8083858489990234, discriminator loss = 1.3162881135940552
# Epochs number 189 | generator loss = 0.8050733804702759, discriminator loss = 1.3178404569625854
# Epochs number 190 | generator loss = 0.8008790612220764, discriminator loss = 1.3185533285140991
# Epochs number 191 | generator loss = 0.8174422383308411, discriminator loss = 1.3064990043640137
# Epochs number 192 | generator loss = 0.817329466342926, discriminator loss = 1.3113877773284912
# Epochs number 193 | generator loss = 0.8113113045692444, discriminator loss = 1.3105969429016113
# Epochs number 194 | generator loss = 0.8225570917129517, discriminator loss = 1.3014057874679565
# Epochs number 195 | generator loss = 0.8084195256233215, discriminator loss = 1.3160090446472168
# Epochs number 196 | generator loss = 0.8087958693504333, discriminator loss = 1.318068265914917
# Epochs number 197 | generator loss = 0.8027966022491455, discriminator loss = 1.318321943283081
# Epochs number 198 | generator loss = 0.8054999709129333, discriminator loss = 1.3127034902572632
# Epochs number 199 | generator loss = 0.8081111311912537, discriminator loss = 1.3160429000854492
# Epochs number 200 | generator loss = 0.8137094974517822, discriminator loss = 1.3112237453460693
# Epochs number 201 | generator loss = 0.8153287172317505, discriminator loss = 1.3119663000106812
# Epochs number 202 | generator loss = 0.8082771897315979, discriminator loss = 1.3104428052902222
# Epochs number 203 | generator loss = 0.8014097213745117, discriminator loss = 1.3211647272109985
# Epochs number 204 | generator loss = 0.8070653676986694, discriminator loss = 1.3083043098449707
# Epochs number 205 | generator loss = 0.8105986714363098, discriminator loss = 1.3117733001708984
# Epochs number 206 | generator loss = 0.8168073892593384, discriminator loss = 1.3170729875564575
# Epochs number 207 | generator loss = 0.8053005933761597, discriminator loss = 1.3163658380508423
# Epochs number 208 | generator loss = 0.800405740737915, discriminator loss = 1.3234649896621704
# Epochs number 209 | generator loss = 0.8108087778091431, discriminator loss = 1.315218210220337
# Epochs number 210 | generator loss = 0.804009735584259, discriminator loss = 1.3221549987792969
# Epochs number 211 | generator loss = 0.7962846159934998, discriminator loss = 1.323585867881775
# Epochs number 212 | generator loss = 0.8049277067184448, discriminator loss = 1.3153611421585083
# Epochs number 213 | generator loss = 0.8131726980209351, discriminator loss = 1.3101391792297363
# Epochs number 214 | generator loss = 0.8000048995018005, discriminator loss = 1.3141205310821533
# Epochs number 215 | generator loss = 0.7942346930503845, discriminator loss = 1.3212045431137085
# Epochs number 216 | generator loss = 0.8015839457511902, discriminator loss = 1.3214777708053589
# Epochs number 217 | generator loss = 0.81047123670578, discriminator loss = 1.3141683340072632
# Epochs number 218 | generator loss = 0.8064794540405273, discriminator loss = 1.3158310651779175
# Epochs number 219 | generator loss = 0.8025970458984375, discriminator loss = 1.3195416927337646
# Epochs number 220 | generator loss = 0.8039115071296692, discriminator loss = 1.3228517770767212
# Epochs number 221 | generator loss = 0.8001458644866943, discriminator loss = 1.317111849784851
# Epochs number 222 | generator loss = 0.8050729036331177, discriminator loss = 1.3139333724975586
# Epochs number 223 | generator loss = 0.810089111328125, discriminator loss = 1.3133682012557983
# Epochs number 224 | generator loss = 0.8037034869194031, discriminator loss = 1.3162022829055786
# Epochs number 225 | generator loss = 0.7972500324249268, discriminator loss = 1.3237404823303223
# Epochs number 226 | generator loss = 0.8002883195877075, discriminator loss = 1.3202859163284302
# Epochs number 227 | generator loss = 0.8032612800598145, discriminator loss = 1.314956545829773
# Epochs number 228 | generator loss = 0.8011360764503479, discriminator loss = 1.3202837705612183
# Epochs number 229 | generator loss = 0.7944130897521973, discriminator loss = 1.3265548944473267
# Epochs number 230 | generator loss = 0.7979878187179565, discriminator loss = 1.3225802183151245
# Epochs number 231 | generator loss = 0.7985439300537109, discriminator loss = 1.325528621673584
# Epochs number 232 | generator loss = 0.7974228858947754, discriminator loss = 1.3244092464447021
# Epochs number 233 | generator loss = 0.8008462190628052, discriminator loss = 1.3194676637649536
# Epochs number 234 | generator loss = 0.7996748089790344, discriminator loss = 1.3231993913650513
# Epochs number 235 | generator loss = 0.7910513877868652, discriminator loss = 1.3223378658294678
# Epochs number 236 | generator loss = 0.7949047088623047, discriminator loss = 1.3170465230941772
# Epochs number 237 | generator loss = 0.7993048429489136, discriminator loss = 1.3156092166900635
# Epochs number 238 | generator loss = 0.8112306594848633, discriminator loss = 1.3247169256210327
# Epochs number 239 | generator loss = 0.8164454698562622, discriminator loss = 1.313833236694336
# Epochs number 240 | generator loss = 0.7953960299491882, discriminator loss = 1.320237636566162
# Epochs number 241 | generator loss = 0.7883127331733704, discriminator loss = 1.3206212520599365
# Epochs number 242 | generator loss = 0.7970395684242249, discriminator loss = 1.3152687549591064
# Epochs number 243 | generator loss = 0.80497807264328, discriminator loss = 1.3138072490692139
# Epochs number 244 | generator loss = 0.8009604215621948, discriminator loss = 1.324052095413208
# Epochs number 245 | generator loss = 0.801753580570221, discriminator loss = 1.3237576484680176
# Epochs number 246 | generator loss = 0.795586347579956, discriminator loss = 1.328295350074768
# Epochs number 247 | generator loss = 0.7880774736404419, discriminator loss = 1.3248317241668701
# Epochs number 248 | generator loss = 0.7946910262107849, discriminator loss = 1.3242684602737427
# Epochs number 249 | generator loss = 0.8087869882583618, discriminator loss = 1.318353533744812
# Epochs number 250 | generator loss = 0.7999489903450012, discriminator loss = 1.3201346397399902

# %%
### Training (On fashion mnist ) ###
import os
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras import backend as K
from tensorflow.keras import optimizers
from tensorflow.keras.datasets import fashion_mnist, mnist
from tensorflow.keras.losses import BinaryCrossentropy

latent_dim = 100
epochs     = 100
batch_size = 64

g = DCGAN().build_generator()
d = DCGAN().build_discriminator()

if(os.path.exists('weights/g_fashion.weights.hdf5')):
    print('[*] Found weights file for generator ...')
    g.load_weights('weights/g_fashion.weights.hdf5')

if(os.path.exists('weights/d_fashion.weights.hdf5')):
    print('[*] Found weights file for discriminator ...')
    d.load_weights('weights/d_fashion.weights.hdf5')
    
g_opt = optimizers.Adam(1e-4)
d_opt = optimizers.Adam(1e-4)

print(g.summary())
print(d.summary())
bce = BinaryCrossentropy(from_logits=True)
def generator_loss(fake_output):
    labels = tf.ones(shape=(K.shape(fake_output)[0], 1))
    loss = bce(labels, fake_output)
    # loss = K.mean(loss)

    return loss

def discriminator_loss(real_output, fake_output):
    zeros = tf.zeros(shape=(K.shape(real_output)[0], 1))
    ones  = tf.ones(shape=(K.shape(real_output)[0], 1))
    
    real_loss = bce(ones, real_output)
    fake_loss = bce(zeros, fake_output)
    loss = real_loss + fake_loss
    # loss = K.mean(loss)
    
    return loss

@tf.function
def train_step(images):
    ### Calculating generator loss ###
    with tf.GradientTape() as g_tape, tf.GradientTape() as d_tape:
        noise = K.random_normal(shape=(K.shape(images)[0], latent_dim))
        generated_images = g(noise, training=True)

        fake_output = d(generated_images, training=True)
        real_output = d(images, training=True)
        
        g_loss = generator_loss(fake_output)
        d_loss = discriminator_loss(real_output, fake_output)
        
    g_gradients = g_tape.gradient(g_loss, g.trainable_variables)
    d_gradients = d_tape.gradient(d_loss, d.trainable_variables)
        
    g_opt.apply_gradients(zip(g_gradients, g.trainable_variables))
    d_opt.apply_gradients(zip(d_gradients, d.trainable_variables))
    
    return g_loss, d_loss
    
(X_train, _), (X_test, _) = fashion_mnist.load_data()

X_train = (X_train - 127.5) / 127.5
num_batches = X_train.shape[0] // batch_size
for i in range(epochs):
    ### Loop thru the batchs ###
    g_losses = []
    d_losses = []
    for j in range(num_batches):
        batch = X_train[j*batch_size:(j+1)*batch_size]
        g_loss, d_loss = train_step(batch)
        g_losses.append(g_loss)
        d_losses.append(d_loss)
    
    if(i % 15 == 0):
        g.save_weights('weights/g_fashion.weights.hdf5')
        d.save_weights('weights/d_fashion.weights.hdf5')
        
    print('Epochs number {} | generator loss = {}, discriminator loss = {}'.format(i+1, np.array(g_losses).mean(), np.array(d_losses).mean()))    
    
### Testing ...  ###
generator = DCGAN().build_generator()
generator.load_weights('weights/g_fashion.weights.hdf5')

latent_dim = 100
num_images = 100
grid_size = 10
noise = K.random_normal(shape=(num_images, latent_dim))
predictions = generator.predict(noise)
predictions = (predictions * 127.5 ) + 127.5
predictions = predictions.astype('uint8')

fig, ax = plt.subplots(grid_size, grid_size, figsize=(30,30))
for i in range(num_images):
    row = i // grid_size
    col = i % grid_size
    
    ax[row][col].imshow(predictions[i], cmap='Greys')

plt.show()
