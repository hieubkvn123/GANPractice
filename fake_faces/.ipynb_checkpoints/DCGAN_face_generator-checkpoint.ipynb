# %%
### Check if GPU is available ###
# !nvidia-smi
# Out:
# Tue Mar  9 12:47:48 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.102.04   Driver Version: 450.102.04   CUDA Version: 11.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  GeForce RTX 208...  Off  | 00000000:01:00.0 Off |                  N/A |
# | 26%   32C    P8     5W / 300W |     31MiB / 11019MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      1132      G   /usr/lib/xorg/Xorg                 12MiB |
# |    0   N/A  N/A      1172      G   /usr/bin/sddm-greeter              16MiB |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # Import Libraries

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

### PyTorch dependencies ###
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from torchvision import datasets
from torchvision import transforms

### Some constants ###
H, W, C = 256, 256, 3
LATENT_DIM = 128

# %% [markdown]
# # Loading and processing data for training

# %%
data_dir = "/home/minhhieu/Desktop/Hieu/datasets/img_align_celeba"
data_transform = transforms.Compose([
    transforms.Resize((H, W)),
    transforms.ToTensor()
])
image_dataset = datasets.ImageFolder(data_dir, transform=data_transform)
dataloader = torch.utils.data.DataLoader(image_dataset, batch_size=64, shuffle=True)

# %%
### Scaling image to [-1, 1] range ###
def scale(img, feature_range=(-1, 1)):    
    # Assuming img is scaled in [0, 1] range
    # scale x by feature range
    x = img * (feature_range[1] - feature_range[0]) + feature_range[0]
    return x

### Show sample image data ###
data_iter = iter(dataloader)
images, _ = data_iter.next()

# Detach the tensors to numpy array and reshape to opencv format
images = images.detach().numpy()
# images = images.reshape(-1, H, W, C)

grid_size = 4
fig, ax = plt.subplots(grid_size,grid_size, figsize=(16, 16))

for i in range(grid_size**2):
    row = i // grid_size
    col = i %  grid_size
    
    image = np.transpose(images[i], (1, 2, 0))
    ax[row][col].imshow(image)
plt.show()

# %% [markdown]
# # Create the models

# %%
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, stride=2, padding=1) # Size / 2 = 128
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, stride=2, padding=1) # Size / 4 = 64
        self.norm2 = nn.BatchNorm2d(64)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, stride=2, padding=1) # Size / 8 = 32
        self.norm3 = nn.BatchNorm2d(128)
        self.conv4 = nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=1) # Size /8 = 32
        self.norm4 = nn.BatchNorm2d(256)
        self.fc    = nn.Linear(256*32*32, 1)
        
    def forward(self, inputs):
        out = F.leaky_relu(self.conv1(inputs), 0.2)
        out = F.leaky_relu(self.norm2(self.conv2(out)), 0.2)
        out = F.leaky_relu(self.norm3(self.conv3(out)), 0.2)
        out = F.leaky_relu(self.norm4(self.conv4(out)), 0.2)
        
        # flatten
        out = out.view(-1, 256*32*32)
        out = self.fc(out)
        
        return out
    
D = Discriminator()

# %%
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        self.fc     = nn.Linear(LATENT_DIM, 256*32*32)
        self.tconv1 = nn.ConvTranspose2d(256, 128, kernel_size=3, stride=1, padding=1, bias=False)
        self.norm1  = nn.BatchNorm2d(128)
        self.tconv2 = nn.ConvTranspose2d(128, 64, kernel_size=4, stride=2, padding=1, bias=False)
        self.norm2  = nn.BatchNorm2d(64)
        self.tconv3 = nn.ConvTranspose2d(64, 32, kernel_size=4, stride=2, padding=1, bias=False)
        self.norm3  = nn.BatchNorm2d(32)
        self.tconv4 = nn.ConvTranspose2d(32, 3, kernel_size=4, stride=2, padding=1, bias=False)
        
    def forward(self, inputs):
        out = self.fc(inputs)
        out = out.view(-1, 256, 32, 32)
        out = F.relu(self.norm1(self.tconv1(out)))
        out = F.relu(self.norm2(self.tconv2(out)))
        out = F.relu(self.norm3(self.tconv3(out)))
        out = self.tconv4(out)
        out = torch.tanh(out)
        
        return out
    
G = Generator()

# %% [markdown]
# # Start training

# %%
# params
lr         = 0.0002
beta1      = 0.5
beta2      = 0.999
epochs     = 1000
batch_size = 64
train_gpu  = False

# Create optimizers for the discriminator D and generator G
d_optimizer = optim.Adam(D.parameters(), lr, [beta1, beta2])
g_optimizer = optim.Adam(G.parameters(), lr, [beta1, beta2])

# Create criterions for the discriminator D and generator G
bce   = nn.BCEWithLogitsLoss()
zeros = torch.zeros(batch_size, 1)
ones  = torch.ones(batch_size, 1) * 0.9 # smooth labels

def generate_img(image_list):
    grid_size = 4
    final_img = None
    hor_imgs = []
    image_list = image_list.detach().numpy()
    for i in range(0, len(image_list), grid_size):
        img1 = np.transpose(image_list[i], (1, 2, 0))
        img2 = np.transpose(image_list[i+1], (1, 2, 0))
        img3 = np.transpose(image_list[i+2], (1, 2, 0))
        img4 = np.transpose(image_list[i+3], (1, 2, 0))

        hor_img = cv2.hconcat([img1, img2, img3, img4])
        hor_imgs.append(hor_img)
            
    final_img = cv2.vconcat([hor_imgs[0], hor_imgs[1], hor_imgs[2], hor_imgs[3]])
    return final_img

def generate_gif(image_list):
    with imageion.get_writer('images/output.gif', mode='I') as writer:
        for image in image_list:
            
    
if(torch.cuda.is_available()):
    print('[INFO] Training with GPU ... ')
    train_gpu = True
    G.cuda()
    D.cuda()
    zeros = zeros.cuda()
    ones = ones.cuda()
    
sample_z = np.random.uniform(-1, 1, size=(16, LATENT_DIM))
sample_z = torch.from_numpy(z).float()
sample_outputs = []

for epoch in range(epochs):
    d_losses = []
    g_losses = []
    for batch_id, (real_images, _) in enumerate(dataloader):
        ### Train discriminator phase ###
        d_optimizer.zero_grad()
        D.train() # turn discriminator to training mode
        G.eval() # turn generator to evaluation mode
        
        real_images = scale(real_images)
        
        # Generate fake images
        z = np.random.uniform(-1, 1, size=(batch_size, LATENT_DIM))
        z = torch.from_numpy(z).float()
        
        if(train_gpu):
            real_images = real_images.cuda()
            z = z.cuda()
            
        fake_images = G(z)
        D_fake = D(fake_images)
        D_real = D(real_images)
        
        d_fake_loss = bce(D_fake, zeros)
        d_real_loss = bce(D_real, ones)
        d_loss = d_fake_loss + d_real_loss 
        d_loss.backward()
        d_optimizer.step()
        
        ### Train generator phase ###
        g_optimizer.zero_grad()
        D.eval() # turn discriminator to evaluation mode
        G.train() # turn generator to training mode
        
        z = np.random.uniform(-1, 1, size=(batch_size, LATENT_DIM))
        z = torch.from_numpy(z).float()
        
        if(train_gpu):
            z = z.cuda()
        
        fake_images = G(z)
        D_fake = D(fake_images)
        g_loss = bce(D_fake, ones)
        g_loss.backward()
        g_optimizer.step()
        
        d_losses.append(d_loss.cpu().detach().numpy())
        g_losses.append(g_loss.cpu().detach().numpy())
        
        print('    BATCH #%d, D loss = %.5f, G loss = %.5f' % (batch_id, d_loss, g_loss))
        
        if((batch_id + 1) % 100 == 0):
            sample_output = generate_img(G(sample_z))
            sample_outputs.append(sample_output)
        
    mean_d_loss = np.array(d_losses).mean()
    mean_g_loss = np.array(g_losses).mean()
    print('EPOCH #[%d/%d], D loss = %.5f, G loss = %.5f' % (epoch, epochs, mean_d_loss, mean_g_loss))
# Out:
# [INFO] Training with GPU ...
#     BATCH #0, D loss = 0.44814, G loss = 0.52020
#     BATCH #1, D loss = 1.75743, G loss = 1.32732
#     BATCH #2, D loss = 4.20230, G loss = 0.61830
#     BATCH #3, D loss = 0.73199, G loss = 0.39395
#     BATCH #4, D loss = 1.05974, G loss = 0.35696
#     BATCH #5, D loss = 0.96109, G loss = 0.38122
#     BATCH #6, D loss = 0.65268, G loss = 0.49923
#     BATCH #7, D loss = 0.63697, G loss = 0.46084
#     BATCH #8, D loss = 0.43635, G loss = 0.46365
#     BATCH #9, D loss = 0.48862, G loss = 0.32588
#     BATCH #10, D loss = 0.51239, G loss = 0.33147
#     BATCH #11, D loss = 0.42533, G loss = 0.32911
#     BATCH #12, D loss = 0.38438, G loss = 0.33796
#     BATCH #13, D loss = 0.37506, G loss = 0.33083
#     BATCH #14, D loss = 0.36537, G loss = 0.33205
#     BATCH #15, D loss = 0.35318, G loss = 0.32935
#     BATCH #16, D loss = 0.35506, G loss = 0.32943
#     BATCH #17, D loss = 0.35753, G loss = 0.33060
#     BATCH #18, D loss = 0.35025, G loss = 0.33189
#     BATCH #19, D loss = 0.36971, G loss = 0.68087
#     BATCH #20, D loss = 0.47509, G loss = 1.03067
#     BATCH #21, D loss = 2.50538, G loss = 15.18353
#     BATCH #22, D loss = 7.19064, G loss = 6.09062
#     BATCH #23, D loss = 1.20189, G loss = 1.50825
#     BATCH #24, D loss = 1.68099, G loss = 0.39538
#     BATCH #25, D loss = 1.55353, G loss = 0.39691
#     BATCH #26, D loss = 1.09221, G loss = 1.52336
#     BATCH #27, D loss = 0.69208, G loss = 0.80560
#     BATCH #28, D loss = 0.82108, G loss = 0.80274
#     BATCH #29, D loss = 0.98589, G loss = 0.47336
#     BATCH #30, D loss = 0.68907, G loss = 0.56827
#     BATCH #31, D loss = 0.68749, G loss = 0.34244
#     BATCH #32, D loss = 0.55761, G loss = 0.35555
#     BATCH #33, D loss = 0.59920, G loss = 0.34532
#     BATCH #34, D loss = 0.55679, G loss = 0.40499
#     BATCH #35, D loss = 0.61599, G loss = 0.41720
#     BATCH #36, D loss = 0.60733, G loss = 0.34016
#     BATCH #37, D loss = 0.76240, G loss = 0.55350
#     BATCH #38, D loss = 1.02224, G loss = 0.40786
#     BATCH #39, D loss = 0.93533, G loss = 0.39098
#     BATCH #40, D loss = 0.87166, G loss = 0.33779
#     BATCH #41, D loss = 0.73666, G loss = 0.48021
#     BATCH #42, D loss = 0.48579, G loss = 0.36647
#     BATCH #43, D loss = 0.59965, G loss = 0.69580
#     BATCH #44, D loss = 1.08336, G loss = 0.42356
#     BATCH #45, D loss = 0.92233, G loss = 0.59300
#     BATCH #46, D loss = 1.00779, G loss = 0.36779
#     BATCH #47, D loss = 0.86754, G loss = 0.33409
#     BATCH #48, D loss = 0.62086, G loss = 0.84846
#     BATCH #49, D loss = 0.86327, G loss = 0.62437
#     BATCH #50, D loss = 1.03498, G loss = 0.62198
#     BATCH #51, D loss = 0.98078, G loss = 0.35429
#     BATCH #52, D loss = 0.72465, G loss = 0.34549
#     BATCH #53, D loss = 0.52593, G loss = 0.69422
#     BATCH #54, D loss = 0.46578, G loss = 0.38658
#     BATCH #55, D loss = 0.58443, G loss = 0.33913
#     BATCH #56, D loss = 0.43981, G loss = 0.34102
#     BATCH #57, D loss = 0.62986, G loss = 0.78740
#     BATCH #58, D loss = 1.24396, G loss = 0.46388
#     BATCH #59, D loss = 1.06067, G loss = 0.52321
#     BATCH #60, D loss = 0.67574, G loss = 1.53478
#     BATCH #61, D loss = 1.41551, G loss = 0.52640
#     BATCH #62, D loss = 1.40777, G loss = 0.46748
#     BATCH #63, D loss = 1.55407, G loss = 0.89808
#     BATCH #64, D loss = 1.41494, G loss = 0.35051
#     BATCH #65, D loss = 0.86542, G loss = 0.70716
#     BATCH #66, D loss = 0.48881, G loss = 0.62283
#     BATCH #67, D loss = 0.54514, G loss = 0.53513
#     BATCH #68, D loss = 0.71017, G loss = 0.35900
#     BATCH #69, D loss = 0.51797, G loss = 0.91383
#     BATCH #70, D loss = 1.06948, G loss = 0.94337
#     BATCH #71, D loss = 3.71841, G loss = 19.27581
#     BATCH #72, D loss = 4.56447, G loss = 17.82842
#     BATCH #73, D loss = 1.10441, G loss = 9.93052
#     BATCH #74, D loss = 1.23095, G loss = 2.05136
#     BATCH #75, D loss = 1.03969, G loss = 0.44476
#     BATCH #76, D loss = 1.20890, G loss = 0.52768
#     BATCH #77, D loss = 0.86891, G loss = 0.34168
#     BATCH #78, D loss = 0.61319, G loss = 0.42719
#     BATCH #79, D loss = 0.86204, G loss = 0.66151
#     BATCH #80, D loss = 1.08401, G loss = 0.49917
#     BATCH #81, D loss = 0.78725, G loss = 0.35402
#     BATCH #82, D loss = 0.59202, G loss = 0.33397
#     BATCH #83, D loss = 0.64875, G loss = 0.59273
#     BATCH #84, D loss = 0.87442, G loss = 0.50735
#     BATCH #85, D loss = 0.80185, G loss = 0.33135
#     BATCH #86, D loss = 0.46933, G loss = 0.61491
#     BATCH #87, D loss = 0.54688, G loss = 0.35968
#     BATCH #88, D loss = 0.51759, G loss = 0.34685
#     BATCH #89, D loss = 0.52490, G loss = 0.39238
#     BATCH #90, D loss = 0.71037, G loss = 0.33312
#     BATCH #91, D loss = 0.55817, G loss = 0.49391
#     BATCH #92, D loss = 0.76580, G loss = 0.76138
#     BATCH #93, D loss = 1.04358, G loss = 0.80569
#     BATCH #94, D loss = 1.11756, G loss = 0.59086
#     BATCH #95, D loss = 0.85791, G loss = 0.34969
#     BATCH #96, D loss = 0.67057, G loss = 0.65215
#     BATCH #97, D loss = 0.47690, G loss = 0.38677
#     BATCH #98, D loss = 0.51012, G loss = 0.36930
#     BATCH #99, D loss = 0.47721, G loss = 0.37359
#     BATCH #100, D loss = 0.40582, G loss = 0.34488
#     BATCH #101, D loss = 0.38283, G loss = 0.32935
#     BATCH #102, D loss = 0.38888, G loss = 0.35696
#     BATCH #103, D loss = 0.46914, G loss = 0.33443
#     BATCH #104, D loss = 0.39702, G loss = 0.33192
#     BATCH #105, D loss = 0.47704, G loss = 0.37410
#     BATCH #106, D loss = 0.79305, G loss = 0.33471
#     BATCH #107, D loss = 0.66703, G loss = 0.37804
#     BATCH #108, D loss = 0.58024, G loss = 0.38532
#     BATCH #109, D loss = 0.41377, G loss = 0.37408
#     BATCH #110, D loss = 0.54731, G loss = 0.34407
#     BATCH #111, D loss = 0.82082, G loss = 0.38993
#     BATCH #112, D loss = 0.64452, G loss = 0.54026
#     BATCH #113, D loss = 0.70268, G loss = 0.41009
#     BATCH #114, D loss = 0.60165, G loss = 0.39233
#     BATCH #115, D loss = 0.63734, G loss = 0.37923
#     BATCH #116, D loss = 0.67190, G loss = 0.33589
#     BATCH #117, D loss = 0.59805, G loss = 0.36194
#     BATCH #118, D loss = 0.66994, G loss = 0.49556
#     BATCH #119, D loss = 0.80783, G loss = 0.48339
#     BATCH #120, D loss = 0.62401, G loss = 0.34515
#     BATCH #121, D loss = 0.75370, G loss = 0.33878
#     BATCH #122, D loss = 1.00702, G loss = 0.38902
#     BATCH #123, D loss = 0.80349, G loss = 0.67918
#     BATCH #124, D loss = 0.97450, G loss = 0.45683
#     BATCH #125, D loss = 0.87517, G loss = 0.46201
#     BATCH #126, D loss = 0.66769, G loss = 0.33565
#     BATCH #127, D loss = 1.03676, G loss = 0.60299
#     BATCH #128, D loss = 1.24189, G loss = 0.51969
#     BATCH #129, D loss = 1.34622, G loss = 0.33465
#     BATCH #130, D loss = 0.86863, G loss = 0.70748
#     BATCH #131, D loss = 0.78345, G loss = 0.36568
#     BATCH #132, D loss = 0.76676, G loss = 0.33028
#     BATCH #133, D loss = 0.63513, G loss = 0.53770
#     BATCH #134, D loss = 0.50408, G loss = 0.34181
#     BATCH #135, D loss = 0.56116, G loss = 0.33115
#     BATCH #136, D loss = 0.38256, G loss = 0.33130
#     BATCH #137, D loss = 0.62803, G loss = 0.56691
#     BATCH #138, D loss = 1.16116, G loss = 0.53616
#     BATCH #139, D loss = 1.27756, G loss = 0.37610
#     BATCH #140, D loss = 0.96133, G loss = 0.39064
#     BATCH #141, D loss = 0.69225, G loss = 0.33899
#     BATCH #142, D loss = 0.47383, G loss = 0.38967
#     BATCH #143, D loss = 0.69786, G loss = 0.42950
#     BATCH #144, D loss = 1.00271, G loss = 0.42421
#     BATCH #145, D loss = 1.07072, G loss = 0.33302
#     BATCH #146, D loss = 0.67473, G loss = 0.45670
#     BATCH #147, D loss = 0.96890, G loss = 0.53703
#     BATCH #148, D loss = 1.12118, G loss = 0.55634
#     BATCH #149, D loss = 1.16382, G loss = 0.42497
#     BATCH #150, D loss = 0.83406, G loss = 0.32869
#     BATCH #151, D loss = 0.72285, G loss = 0.33254
#     BATCH #152, D loss = 0.52768, G loss = 0.32812
#     BATCH #153, D loss = 0.56023, G loss = 0.32737
#     BATCH #154, D loss = 0.52092, G loss = 0.35068
#     BATCH #155, D loss = 0.49868, G loss = 0.35678
#     BATCH #156, D loss = 0.70305, G loss = 0.34656
#     BATCH #157, D loss = 0.58743, G loss = 0.33218
#     BATCH #158, D loss = 0.42187, G loss = 0.33175
#     BATCH #159, D loss = 0.38708, G loss = 0.35072
#     BATCH #160, D loss = 0.39248, G loss = 0.33256
#     BATCH #161, D loss = 0.37864, G loss = 0.33303
#     BATCH #162, D loss = 0.37212, G loss = 0.33018
#     BATCH #163, D loss = 0.36804, G loss = 0.32789
#     BATCH #164, D loss = 0.37738, G loss = 0.32814
#     BATCH #165, D loss = 0.37921, G loss = 0.33506
#     BATCH #166, D loss = 0.42682, G loss = 0.32655
#     BATCH #167, D loss = 0.38786, G loss = 0.32866
#     BATCH #168, D loss = 0.36381, G loss = 0.32784
#     BATCH #169, D loss = 0.38467, G loss = 0.32669
#     BATCH #170, D loss = 0.37215, G loss = 0.32871
#     BATCH #171, D loss = 0.37274, G loss = 0.32953
#     BATCH #172, D loss = 0.36122, G loss = 0.32736
#     BATCH #173, D loss = 0.38282, G loss = 0.32976
#     BATCH #174, D loss = 0.48489, G loss = 0.39462
#     BATCH #175, D loss = 0.82638, G loss = 0.36797
#     BATCH #176, D loss = 0.80195, G loss = 0.32888
#     BATCH #177, D loss = 0.47664, G loss = 0.40509
#     BATCH #178, D loss = 0.86500, G loss = 0.40036
#     BATCH #179, D loss = 1.26632, G loss = 0.38167
#     BATCH #180, D loss = 1.49351, G loss = 0.36654
#     BATCH #181, D loss = 1.16309, G loss = 0.55915
#     BATCH #182, D loss = 0.79371, G loss = 0.33567
#     BATCH #183, D loss = 0.52953, G loss = 0.40620
#     BATCH #184, D loss = 0.42328, G loss = 0.36177
#     BATCH #185, D loss = 0.43530, G loss = 0.39295
#     BATCH #186, D loss = 0.45179, G loss = 0.33282
#     BATCH #187, D loss = 0.42710, G loss = 0.33366
#     BATCH #188, D loss = 0.50370, G loss = 0.35138
#     BATCH #189, D loss = 0.42296, G loss = 0.33059
#     BATCH #190, D loss = 0.37854, G loss = 0.34329
#     BATCH #191, D loss = 0.44073, G loss = 0.33944
#     BATCH #192, D loss = 0.65724, G loss = 0.32847
#     BATCH #193, D loss = 0.49591, G loss = 0.44495
#     BATCH #194, D loss = 0.54266, G loss = 0.37408
#     BATCH #195, D loss = 0.69367, G loss = 0.36708
#     BATCH #196, D loss = 0.65699, G loss = 0.33213
#     BATCH #197, D loss = 0.63764, G loss = 0.35350
#     BATCH #198, D loss = 0.73724, G loss = 0.33074
#     BATCH #199, D loss = 0.66664, G loss = 0.36511
#     BATCH #200, D loss = 0.66445, G loss = 0.33900
#     BATCH #201, D loss = 0.63511, G loss = 0.32752
#     BATCH #202, D loss = 0.43152, G loss = 0.32879
#     BATCH #203, D loss = 0.49522, G loss = 0.42455
#     BATCH #204, D loss = 0.75503, G loss = 0.40540
#     BATCH #205, D loss = 0.77953, G loss = 0.33226
#     BATCH #206, D loss = 0.40039, G loss = 0.37240
#     BATCH #207, D loss = 1.43170, G loss = 0.57121
#     BATCH #208, D loss = 2.49960, G loss = 7.66971
#     BATCH #209, D loss = 1.54913, G loss = 9.56832
#     BATCH #210, D loss = 0.92302, G loss = 10.01061
#     BATCH #211, D loss = 1.26304, G loss = 0.44592
#     BATCH #212, D loss = 0.97421, G loss = 0.57482
#     BATCH #213, D loss = 1.25852, G loss = 0.42682
#     BATCH #214, D loss = 0.94384, G loss = 0.62657
#     BATCH #215, D loss = 0.53442, G loss = 0.46617
#     BATCH #216, D loss = 0.80346, G loss = 0.54426
#     BATCH #217, D loss = 0.81515, G loss = 0.45418
#     BATCH #218, D loss = 0.86513, G loss = 0.40899
#     BATCH #219, D loss = 0.50107, G loss = 0.69247
#     BATCH #220, D loss = 0.68272, G loss = 0.62794
#     BATCH #221, D loss = 1.04689, G loss = 0.59124
#     BATCH #222, D loss = 1.15432, G loss = 0.33843
#     BATCH #223, D loss = 0.90825, G loss = 0.38187
#     BATCH #224, D loss = 0.89719, G loss = 0.33423
#     BATCH #225, D loss = 0.67435, G loss = 0.42681
#     BATCH #226, D loss = 0.58366, G loss = 0.40723
#     BATCH #227, D loss = 0.51105, G loss = 0.36169
#     BATCH #228, D loss = 0.45775, G loss = 0.36178
#     BATCH #229, D loss = 0.65717, G loss = 0.59531
#     BATCH #230, D loss = 1.07126, G loss = 0.56628
#     BATCH #231, D loss = 1.14391, G loss = 0.36707
#     BATCH #232, D loss = 0.80272, G loss = 0.46697
#     BATCH #233, D loss = 0.65833, G loss = 0.34726
#     BATCH #234, D loss = 0.43588, G loss = 0.34413
#     BATCH #235, D loss = 0.37533, G loss = 0.34366
#     BATCH #236, D loss = 0.36968, G loss = 0.33167
#     BATCH #237, D loss = 0.37906, G loss = 0.33140
#     BATCH #238, D loss = 0.38441, G loss = 0.33083
#     BATCH #239, D loss = 0.39764, G loss = 0.34841
#     BATCH #240, D loss = 0.42568, G loss = 0.36163
#     BATCH #241, D loss = 0.60918, G loss = 0.33056
#     BATCH #242, D loss = 0.49437, G loss = 0.45118
#     BATCH #243, D loss = 0.59941, G loss = 0.49479
#     BATCH #244, D loss = 1.00116, G loss = 0.47730
#     BATCH #245, D loss = 0.98491, G loss = 0.33006
#     BATCH #246, D loss = 0.71126, G loss = 0.49739
#     BATCH #247, D loss = 0.71553, G loss = 0.33050
#     BATCH #248, D loss = 0.66693, G loss = 0.32996
#     BATCH #249, D loss = 0.74012, G loss = 0.35966
#     BATCH #250, D loss = 0.59841, G loss = 0.37533
#     BATCH #251, D loss = 0.51503, G loss = 0.33494
#     BATCH #252, D loss = 0.47263, G loss = 0.34886
#     BATCH #253, D loss = 0.40181, G loss = 0.41523
#     BATCH #254, D loss = 0.37321, G loss = 0.36916
#     BATCH #255, D loss = 0.39721, G loss = 0.36235
#     BATCH #256, D loss = 0.54570, G loss = 0.33934
#     BATCH #257, D loss = 0.44521, G loss = 0.36973
#     BATCH #258, D loss = 0.63801, G loss = 0.48919
#     BATCH #259, D loss = 1.07712, G loss = 0.46808
#     BATCH #260, D loss = 1.14913, G loss = 0.34227
#     BATCH #261, D loss = 0.89150, G loss = 0.40372
#     BATCH #262, D loss = 0.44594, G loss = 0.39006
#     BATCH #263, D loss = 0.55104, G loss = 0.38776
#     BATCH #264, D loss = 0.73824, G loss = 0.37316
#     BATCH #265, D loss = 0.68664, G loss = 0.32891
#     BATCH #266, D loss = 0.46308, G loss = 0.36607
#     BATCH #267, D loss = 0.49343, G loss = 0.32943
#     BATCH #268, D loss = 0.64989, G loss = 0.32886
#     BATCH #269, D loss = 0.53155, G loss = 0.36095
#     BATCH #270, D loss = 0.40978, G loss = 0.33618
#     BATCH #271, D loss = 0.44378, G loss = 0.33318
#     BATCH #272, D loss = 0.40405, G loss = 0.33658
#     BATCH #273, D loss = 0.36592, G loss = 0.32818
#     BATCH #274, D loss = 0.37053, G loss = 0.33338
#     BATCH #275, D loss = 0.37831, G loss = 0.32842
#     BATCH #276, D loss = 0.40805, G loss = 0.34211
#     BATCH #277, D loss = 0.36105, G loss = 0.33777
#     BATCH #278, D loss = 0.76258, G loss = 0.57656
#     BATCH #279, D loss = 1.30701, G loss = 0.59692
#     BATCH #280, D loss = 1.49060, G loss = 0.43270
#     BATCH #281, D loss = 1.28008, G loss = 0.32764
#     BATCH #282, D loss = 0.88260, G loss = 0.35664
#     BATCH #283, D loss = 0.42194, G loss = 0.37924
#     BATCH #284, D loss = 0.90647, G loss = 0.33674
#     BATCH #285, D loss = 1.21347, G loss = 0.33794
#     BATCH #286, D loss = 1.48468, G loss = 0.32985
#     BATCH #287, D loss = 1.36500, G loss = 0.34182
#     BATCH #288, D loss = 0.98631, G loss = 0.34012
#     BATCH #289, D loss = 0.54850, G loss = 0.34773
#     BATCH #290, D loss = 0.90123, G loss = 0.34219
#     BATCH #291, D loss = 0.86378, G loss = 0.33010
#     BATCH #292, D loss = 0.87202, G loss = 0.35843
#     BATCH #293, D loss = 0.76963, G loss = 0.33166
#     BATCH #294, D loss = 0.46098, G loss = 0.35752
#     BATCH #295, D loss = 0.64122, G loss = 0.35984
#     BATCH #296, D loss = 0.72153, G loss = 0.42857
#     BATCH #297, D loss = 0.67922, G loss = 0.32787
#     BATCH #298, D loss = 0.56311, G loss = 0.32981
#     BATCH #299, D loss = 0.50965, G loss = 0.38837
#     BATCH #300, D loss = 0.49064, G loss = 0.35428
#     BATCH #301, D loss = 0.39975, G loss = 0.33505
#     BATCH #302, D loss = 0.37992, G loss = 0.34277
#     BATCH #303, D loss = 0.38615, G loss = 0.32771
#     BATCH #304, D loss = 0.37067, G loss = 0.33190
#     BATCH #305, D loss = 0.37821, G loss = 0.32882
#     BATCH #306, D loss = 0.39532, G loss = 0.32640
#     BATCH #307, D loss = 0.36202, G loss = 0.33253
#     BATCH #308, D loss = 0.37364, G loss = 0.32923
#     BATCH #309, D loss = 0.36182, G loss = 0.33079
#     BATCH #310, D loss = 0.35105, G loss = 0.32682
#     BATCH #311, D loss = 0.35348, G loss = 0.32646
#     BATCH #312, D loss = 0.36371, G loss = 0.33226
#     BATCH #313, D loss = 0.38250, G loss = 0.32694
#     BATCH #314, D loss = 0.35167, G loss = 0.32734
#     BATCH #315, D loss = 0.35379, G loss = 0.32637
#     BATCH #316, D loss = 0.37500, G loss = 0.32810
#     BATCH #317, D loss = 0.36099, G loss = 0.32880
#     BATCH #318, D loss = 0.35363, G loss = 0.32749
#     BATCH #319, D loss = 0.33808, G loss = 0.32639
#     BATCH #320, D loss = 0.34277, G loss = 0.32668
#     BATCH #321, D loss = 0.34223, G loss = 0.32704
#     BATCH #322, D loss = 0.34259, G loss = 0.32718
#     BATCH #323, D loss = 0.33864, G loss = 0.32600
#     BATCH #324, D loss = 0.35569, G loss = 0.32807
#     BATCH #325, D loss = 0.35067, G loss = 0.32617
#     BATCH #326, D loss = 0.35202, G loss = 0.32707
#     BATCH #327, D loss = 0.35299, G loss = 0.33086
#     BATCH #328, D loss = 0.39331, G loss = 0.32627
#     BATCH #329, D loss = 0.42720, G loss = 0.34814
#     BATCH #330, D loss = 0.53066, G loss = 0.32727
#     BATCH #331, D loss = 0.44648, G loss = 0.35612
#     BATCH #332, D loss = 0.43114, G loss = 0.33133
#     BATCH #333, D loss = 0.46505, G loss = 0.32917
#     BATCH #334, D loss = 0.43104, G loss = 0.32604
#     BATCH #335, D loss = 0.39077, G loss = 0.34943
#     BATCH #336, D loss = 0.40770, G loss = 0.33492
#     BATCH #337, D loss = 0.37253, G loss = 0.32742
#     BATCH #338, D loss = 0.39889, G loss = 0.32836
#     BATCH #339, D loss = 0.46139, G loss = 0.32988
#     BATCH #340, D loss = 0.42831, G loss = 0.32617
#     BATCH #341, D loss = 0.42229, G loss = 0.33340
#     BATCH #342, D loss = 0.41408, G loss = 0.32608
#     BATCH #343, D loss = 0.36038, G loss = 0.33881
#     BATCH #344, D loss = 0.38496, G loss = 0.33465
#     BATCH #345, D loss = 0.47416, G loss = 0.32839
#     BATCH #346, D loss = 0.39042, G loss = 0.32919
#     BATCH #347, D loss = 0.40462, G loss = 0.32606
#     BATCH #348, D loss = 0.43745, G loss = 0.33786
#     BATCH #349, D loss = 0.35687, G loss = 0.34677
#     BATCH #350, D loss = 0.38278, G loss = 0.32682
#     BATCH #351, D loss = 0.40277, G loss = 0.32627
#     BATCH #352, D loss = 0.37697, G loss = 0.32720
#     BATCH #353, D loss = 0.36238, G loss = 0.32609
#     BATCH #354, D loss = 0.35141, G loss = 0.32755
#     BATCH #355, D loss = 0.34359, G loss = 0.32897
#     BATCH #356, D loss = 0.34678, G loss = 0.32595
#     BATCH #357, D loss = 0.35732, G loss = 0.32646
#     BATCH #358, D loss = 0.34141, G loss = 0.32650
#     BATCH #359, D loss = 0.34179, G loss = 0.32920
#     BATCH #360, D loss = 0.39078, G loss = 0.34133
#     BATCH #361, D loss = 0.50001, G loss = 0.32873
#     BATCH #362, D loss = 0.41799, G loss = 0.33222
#     BATCH #363, D loss = 0.44157, G loss = 0.33463
#     BATCH #364, D loss = 0.55197, G loss = 0.32594
#     BATCH #365, D loss = 0.43209, G loss = 0.34259
#     BATCH #366, D loss = 0.48521, G loss = 0.35951
#     BATCH #367, D loss = 0.55580, G loss = 0.36144
#     BATCH #368, D loss = 0.45490, G loss = 0.32797
#     BATCH #369, D loss = 0.45337, G loss = 0.32769
#     BATCH #370, D loss = 0.42868, G loss = 0.34917
#     BATCH #371, D loss = 0.37808, G loss = 0.36762
#     BATCH #372, D loss = 0.46507, G loss = 0.34172
#     BATCH #373, D loss = 0.54781, G loss = 0.34336
#     BATCH #374, D loss = 0.47369, G loss = 0.32706
#     BATCH #375, D loss = 0.50812, G loss = 0.35093
#     BATCH #376, D loss = 0.61608, G loss = 0.33153
#     BATCH #377, D loss = 0.52941, G loss = 0.33555
#     BATCH #378, D loss = 0.45688, G loss = 0.32710
#     BATCH #379, D loss = 0.41574, G loss = 0.33521
#     BATCH #380, D loss = 0.37756, G loss = 0.32895
#     BATCH #381, D loss = 0.36018, G loss = 0.32809
#     BATCH #382, D loss = 0.42290, G loss = 0.32679
#     BATCH #383, D loss = 0.41997, G loss = 0.33457
#     BATCH #384, D loss = 0.49155, G loss = 0.32659
#     BATCH #385, D loss = 0.40245, G loss = 0.33604
#     BATCH #386, D loss = 0.48438, G loss = 0.34381
#     BATCH #387, D loss = 0.52593, G loss = 0.33530
#     BATCH #388, D loss = 0.49775, G loss = 0.33022
#     BATCH #389, D loss = 0.43525, G loss = 0.32632
#     BATCH #390, D loss = 0.48690, G loss = 0.33984
#     BATCH #391, D loss = 0.40441, G loss = 0.35666
#     BATCH #392, D loss = 0.51436, G loss = 0.35619
#     BATCH #393, D loss = 0.68214, G loss = 0.35274
#     BATCH #394, D loss = 0.55076, G loss = 0.32858
#     BATCH #395, D loss = 0.41359, G loss = 0.32832
#     BATCH #396, D loss = 0.36660, G loss = 0.32623
#     BATCH #397, D loss = 0.36339, G loss = 0.32673
#     BATCH #398, D loss = 0.39834, G loss = 0.33205
#     BATCH #399, D loss = 0.36501, G loss = 0.33647
#     BATCH #400, D loss = 0.37518, G loss = 0.32842
#     BATCH #401, D loss = 0.35126, G loss = 0.32589
#     BATCH #402, D loss = 0.35443, G loss = 0.32610
#     BATCH #403, D loss = 0.37101, G loss = 0.33116
#     BATCH #404, D loss = 0.41783, G loss = 0.32862
#     BATCH #405, D loss = 0.35927, G loss = 0.32615
#     BATCH #406, D loss = 0.34000, G loss = 0.32580
#     BATCH #407, D loss = 0.33618, G loss = 0.32617
#     BATCH #408, D loss = 0.35307, G loss = 0.32648
#     BATCH #409, D loss = 0.42681, G loss = 0.32616
#     BATCH #410, D loss = 0.34813, G loss = 0.32734
#     BATCH #411, D loss = 0.34217, G loss = 0.32747
#     BATCH #412, D loss = 0.35784, G loss = 0.32588
#     BATCH #413, D loss = 0.40250, G loss = 0.32576
#     BATCH #414, D loss = 0.34209, G loss = 0.32578
#     BATCH #415, D loss = 0.33903, G loss = 0.32572
#     BATCH #416, D loss = 0.35709, G loss = 0.32597
#     BATCH #417, D loss = 0.35502, G loss = 0.32576
#     BATCH #418, D loss = 0.37288, G loss = 0.32925
#     BATCH #419, D loss = 0.35232, G loss = 0.32609
#     BATCH #420, D loss = 0.38793, G loss = 0.32653
#     BATCH #421, D loss = 0.35084, G loss = 0.32627
#     BATCH #422, D loss = 0.36292, G loss = 0.32680
#     BATCH #423, D loss = 0.35442, G loss = 0.32570
#     BATCH #424, D loss = 0.34722, G loss = 0.32627
#     BATCH #425, D loss = 0.35005, G loss = 0.32555
#     BATCH #426, D loss = 0.34159, G loss = 0.32558
#     BATCH #427, D loss = 0.34486, G loss = 0.32559
#     BATCH #428, D loss = 0.34993, G loss = 0.32649
#     BATCH #429, D loss = 0.34239, G loss = 0.32582
#     BATCH #430, D loss = 0.33974, G loss = 0.32583
#     BATCH #431, D loss = 0.33693, G loss = 0.32577
#     BATCH #432, D loss = 0.33681, G loss = 0.32627
#     BATCH #433, D loss = 0.33321, G loss = 0.32625
#     BATCH #434, D loss = 0.33697, G loss = 0.32610
#     BATCH #435, D loss = 0.33179, G loss = 0.32583
#     BATCH #436, D loss = 0.33620, G loss = 0.32627
#     BATCH #437, D loss = 0.35880, G loss = 0.32588
#     BATCH #438, D loss = 0.36905, G loss = 0.32549
#     BATCH #439, D loss = 0.39969, G loss = 0.32658
#     BATCH #440, D loss = 0.34898, G loss = 0.32885
#     BATCH #441, D loss = 0.45632, G loss = 0.35085
#     BATCH #442, D loss = 0.72736, G loss = 0.33434
#     BATCH #443, D loss = 0.67731, G loss = 0.32714
#     BATCH #444, D loss = 0.40357, G loss = 0.32996
#     BATCH #445, D loss = 0.63217, G loss = 0.32906
#     BATCH #446, D loss = 0.94787, G loss = 0.33169
#     BATCH #447, D loss = 1.05839, G loss = 0.34649
#     BATCH #448, D loss = 0.71393, G loss = 0.35675
#     BATCH #449, D loss = 0.44393, G loss = 0.32568
#     BATCH #450, D loss = 0.34849, G loss = 0.32856
#     BATCH #451, D loss = 0.37504, G loss = 0.33660
#     BATCH #452, D loss = 0.43005, G loss = 0.32623
#     BATCH #453, D loss = 0.37211, G loss = 0.33404
#     BATCH #454, D loss = 0.38433, G loss = 0.32600
#     BATCH #455, D loss = 0.44243, G loss = 0.33043
#     BATCH #456, D loss = 0.39172, G loss = 0.33061
#     BATCH #457, D loss = 0.50370, G loss = 0.34449
#     BATCH #458, D loss = 0.64199, G loss = 0.32935
#     BATCH #459, D loss = 0.55856, G loss = 0.33365
#     BATCH #460, D loss = 0.72885, G loss = 0.36111
#     BATCH #461, D loss = 0.67406, G loss = 0.33178
#     BATCH #462, D loss = 0.62380, G loss = 0.34814
#     BATCH #463, D loss = 0.80340, G loss = 0.34832
#     BATCH #464, D loss = 1.03476, G loss = 0.32728
#     BATCH #465, D loss = 1.02830, G loss = 0.32890
#     BATCH #466, D loss = 0.76016, G loss = 0.32852
#     BATCH #467, D loss = 0.63917, G loss = 0.32930
#     BATCH #468, D loss = 0.69767, G loss = 0.33061
#     BATCH #469, D loss = 0.69825, G loss = 0.34416
#     BATCH #470, D loss = 0.48163, G loss = 0.34217
#     BATCH #471, D loss = 0.56783, G loss = 0.33957
#     BATCH #472, D loss = 0.95730, G loss = 0.32734
#     BATCH #473, D loss = 0.99738, G loss = 0.33415
#     BATCH #474, D loss = 0.75269, G loss = 0.32822
#     BATCH #475, D loss = 0.50622, G loss = 0.32627
#     BATCH #476, D loss = 0.41684, G loss = 0.32647
#     BATCH #477, D loss = 0.44302, G loss = 0.33173
#     BATCH #478, D loss = 0.41658, G loss = 0.32831
#     BATCH #479, D loss = 0.55199, G loss = 0.33158
#     BATCH #480, D loss = 0.38547, G loss = 0.34931
#     BATCH #481, D loss = 0.55275, G loss = 0.33313
#     BATCH #482, D loss = 0.85961, G loss = 0.32640
#     BATCH #483, D loss = 0.77874, G loss = 0.32626
#     BATCH #484, D loss = 0.46643, G loss = 0.32627
#     BATCH #485, D loss = 0.87440, G loss = 0.34973
#     BATCH #486, D loss = 1.29976, G loss = 0.33588
#     BATCH #487, D loss = 1.51659, G loss = 0.32845
#     BATCH #488, D loss = 1.26886, G loss = 0.32999
#     BATCH #489, D loss = 0.77008, G loss = 0.32567
#     BATCH #490, D loss = 0.53682, G loss = 0.37150
#     BATCH #491, D loss = 0.50644, G loss = 0.32867
#     BATCH #492, D loss = 0.55943, G loss = 0.32592
#     BATCH #493, D loss = 0.43008, G loss = 0.32647
#     BATCH #494, D loss = 0.44849, G loss = 0.32718
#     BATCH #495, D loss = 0.61219, G loss = 0.33262
#     BATCH #496, D loss = 0.60123, G loss = 0.32895
#     BATCH #497, D loss = 0.34699, G loss = 0.32889
#     BATCH #498, D loss = 0.57696, G loss = 0.36309
#     BATCH #499, D loss = 1.00544, G loss = 0.34597
#     BATCH #500, D loss = 1.10012, G loss = 0.32822
#     BATCH #501, D loss = 0.75225, G loss = 0.33607
#     BATCH #502, D loss = 0.53653, G loss = 0.34627
#     BATCH #503, D loss = 0.80407, G loss = 0.50814
#     BATCH #504, D loss = 1.02842, G loss = 0.47256
#     BATCH #505, D loss = 1.25773, G loss = 0.36321
#     BATCH #506, D loss = 0.85621, G loss = 0.32950
#     BATCH #507, D loss = 0.45772, G loss = 0.35167
#     BATCH #508, D loss = 0.53269, G loss = 0.52042
#     BATCH #509, D loss = 0.82269, G loss = 0.35875
#     BATCH #510, D loss = 0.76383, G loss = 0.33200
#     BATCH #511, D loss = 0.51929, G loss = 0.38064
#     BATCH #512, D loss = 0.68953, G loss = 0.43084
#     BATCH #513, D loss = 0.76753, G loss = 0.33028
#     BATCH #514, D loss = 0.81117, G loss = 0.37728
#     BATCH #515, D loss = 0.56122, G loss = 0.33651
#     BATCH #516, D loss = 0.52405, G loss = 0.32988
#     BATCH #517, D loss = 0.41076, G loss = 0.33268
#     BATCH #518, D loss = 0.39565, G loss = 0.33136
#     BATCH #519, D loss = 0.38700, G loss = 0.32696
#     BATCH #520, D loss = 0.36918, G loss = 0.32619
#     BATCH #521, D loss = 0.36203, G loss = 0.32660
#     BATCH #522, D loss = 0.37210, G loss = 0.36534
#     BATCH #523, D loss = 0.39909, G loss = 0.35442
#     BATCH #524, D loss = 0.39915, G loss = 0.32780
#     BATCH #525, D loss = 0.38202, G loss = 0.32660
#     BATCH #526, D loss = 0.34800, G loss = 0.32631
#     BATCH #527, D loss = 0.36073, G loss = 0.33061
#     BATCH #528, D loss = 0.35123, G loss = 0.32629
#     BATCH #529, D loss = 0.34087, G loss = 0.32634
#     BATCH #530, D loss = 0.34805, G loss = 0.32770
#     BATCH #531, D loss = 0.34609, G loss = 0.32795
#     BATCH #532, D loss = 0.36183, G loss = 0.32583
#     BATCH #533, D loss = 0.34726, G loss = 0.32606
#     BATCH #534, D loss = 0.33939, G loss = 0.32603
#     BATCH #535, D loss = 0.34354, G loss = 0.32638
#     BATCH #536, D loss = 0.34517, G loss = 0.32673
#     BATCH #537, D loss = 0.35101, G loss = 0.32753
#     BATCH #538, D loss = 0.35354, G loss = 0.32637
#     BATCH #539, D loss = 0.37398, G loss = 0.32784
#     BATCH #540, D loss = 0.35267, G loss = 0.32615
#     BATCH #541, D loss = 0.33970, G loss = 0.32663
#     BATCH #542, D loss = 0.33332, G loss = 0.32610
#     BATCH #543, D loss = 0.33614, G loss = 0.32653
#     BATCH #544, D loss = 0.34057, G loss = 0.32628
#     BATCH #545, D loss = 0.33823, G loss = 0.32805
#     BATCH #546, D loss = 0.34778, G loss = 0.32560
#     BATCH #547, D loss = 0.34896, G loss = 0.33184
#     BATCH #548, D loss = 0.35290, G loss = 0.32666
#     BATCH #549, D loss = 0.33513, G loss = 0.32624
#     BATCH #550, D loss = 0.35834, G loss = 0.32820
#     BATCH #551, D loss = 0.37385, G loss = 0.32589
#     BATCH #552, D loss = 0.34835, G loss = 0.32802
#     BATCH #553, D loss = 0.39239, G loss = 0.33084
#     BATCH #554, D loss = 0.44237, G loss = 0.32548
#     BATCH #555, D loss = 0.37323, G loss = 0.32807
#     BATCH #556, D loss = 0.40027, G loss = 0.33037
#     BATCH #557, D loss = 0.45797, G loss = 0.32589
#     BATCH #558, D loss = 0.35994, G loss = 0.32959
#     BATCH #559, D loss = 0.43202, G loss = 0.32773
#     BATCH #560, D loss = 0.48919, G loss = 0.32568
#     BATCH #561, D loss = 0.46536, G loss = 0.33476
#     BATCH #562, D loss = 0.35446, G loss = 0.33192
#     BATCH #563, D loss = 0.35442, G loss = 0.32575
#     BATCH #564, D loss = 0.37500, G loss = 0.32577
#     BATCH #565, D loss = 0.33960, G loss = 0.32572
#     BATCH #566, D loss = 0.34395, G loss = 0.33213
#     BATCH #567, D loss = 0.35836, G loss = 0.32788
#     BATCH #568, D loss = 0.34170, G loss = 0.32574
#     BATCH #569, D loss = 0.38963, G loss = 0.32579
#     BATCH #570, D loss = 0.47052, G loss = 0.32803
#     BATCH #571, D loss = 0.39124, G loss = 0.32921
#     BATCH #572, D loss = 0.37759, G loss = 0.33226
#     BATCH #573, D loss = 0.38186, G loss = 0.32940
#     BATCH #574, D loss = 0.35316, G loss = 0.32597
#     BATCH #575, D loss = 0.34336, G loss = 0.32781
#     BATCH #576, D loss = 0.33747, G loss = 0.32758
#     BATCH #577, D loss = 0.34512, G loss = 0.32561
#     BATCH #578, D loss = 0.34769, G loss = 0.32628
#     BATCH #579, D loss = 0.34013, G loss = 0.32570
#     BATCH #580, D loss = 0.33873, G loss = 0.32616
#     BATCH #581, D loss = 0.33547, G loss = 0.32579
#     BATCH #582, D loss = 0.34221, G loss = 0.32552
#     BATCH #583, D loss = 0.33222, G loss = 0.32555
#     BATCH #584, D loss = 0.33447, G loss = 0.32683
#     BATCH #585, D loss = 0.34420, G loss = 0.32556
#     BATCH #586, D loss = 0.33280, G loss = 0.32643
#     BATCH #587, D loss = 0.34368, G loss = 0.32581
#     BATCH #588, D loss = 0.35666, G loss = 0.32588
#     BATCH #589, D loss = 0.33333, G loss = 0.32600
#     BATCH #590, D loss = 0.33524, G loss = 0.32570
#     BATCH #591, D loss = 0.34556, G loss = 0.32648
#     BATCH #592, D loss = 0.33449, G loss = 0.32707
#     BATCH #593, D loss = 0.33596, G loss = 0.32679
#     BATCH #594, D loss = 0.33306, G loss = 0.32548
#     BATCH #595, D loss = 0.33100, G loss = 0.32541
#     BATCH #596, D loss = 0.33412, G loss = 0.32550
#     BATCH #597, D loss = 0.33454, G loss = 0.32553
#     BATCH #598, D loss = 0.33168, G loss = 0.32553
#     BATCH #599, D loss = 0.33117, G loss = 0.32609
#     BATCH #600, D loss = 0.33250, G loss = 0.32554
#     BATCH #601, D loss = 0.33165, G loss = 0.32561
#     BATCH #602, D loss = 0.32927, G loss = 0.32547
#     BATCH #603, D loss = 0.33026, G loss = 0.32584
#     BATCH #604, D loss = 0.33698, G loss = 0.32628
#     BATCH #605, D loss = 0.35287, G loss = 0.32539
#     BATCH #606, D loss = 0.34645, G loss = 0.32548
#     BATCH #607, D loss = 0.33986, G loss = 0.32595
#     BATCH #608, D loss = 0.33325, G loss = 0.32549
#     BATCH #609, D loss = 0.33152, G loss = 0.32578
#     BATCH #610, D loss = 0.33398, G loss = 0.32540
#     BATCH #611, D loss = 0.33309, G loss = 0.32559
#     BATCH #612, D loss = 0.33648, G loss = 0.32628
#     BATCH #613, D loss = 0.36691, G loss = 0.32542
#     BATCH #614, D loss = 0.37263, G loss = 0.32851
#     BATCH #615, D loss = 0.40698, G loss = 0.32542
#     BATCH #616, D loss = 0.33427, G loss = 0.32820
#     BATCH #617, D loss = 0.40025, G loss = 0.33022
#     BATCH #618, D loss = 0.47592, G loss = 0.32652
#     BATCH #619, D loss = 0.43077, G loss = 0.32683
#     BATCH #620, D loss = 0.42077, G loss = 0.32807
#     BATCH #621, D loss = 0.55348, G loss = 0.33496
#     BATCH #622, D loss = 0.46127, G loss = 0.32962
#     BATCH #623, D loss = 0.46520, G loss = 0.33105
#     BATCH #624, D loss = 0.50184, G loss = 0.32622
#     BATCH #625, D loss = 0.40975, G loss = 0.33803
#     BATCH #626, D loss = 0.50077, G loss = 0.32685
#     BATCH #627, D loss = 0.61054, G loss = 0.32629
#     BATCH #628, D loss = 0.64910, G loss = 0.33182
#     BATCH #629, D loss = 0.47482, G loss = 0.34011
#     BATCH #630, D loss = 0.60505, G loss = 0.35826
#     BATCH #631, D loss = 0.80154, G loss = 0.32637
#     BATCH #632, D loss = 0.79022, G loss = 0.38135
#     BATCH #633, D loss = 0.50205, G loss = 0.33639
#     BATCH #634, D loss = 0.39732, G loss = 0.32603
#     BATCH #635, D loss = 0.64267, G loss = 0.40802
#     BATCH #636, D loss = 0.50678, G loss = 0.39516
#     BATCH #637, D loss = 0.51073, G loss = 0.32957
#     BATCH #638, D loss = 0.42298, G loss = 0.36784
#     BATCH #639, D loss = 0.49933, G loss = 0.33101
#     BATCH #640, D loss = 0.47857, G loss = 0.32576
#     BATCH #641, D loss = 0.40745, G loss = 0.34364
#     BATCH #642, D loss = 0.46057, G loss = 0.33021
#     BATCH #643, D loss = 0.57393, G loss = 0.32599
#     BATCH #644, D loss = 0.59652, G loss = 0.32752
#     BATCH #645, D loss = 0.37279, G loss = 0.32657
#     BATCH #646, D loss = 0.64152, G loss = 0.32963
#     BATCH #647, D loss = 0.84124, G loss = 0.32679
#     BATCH #648, D loss = 0.74875, G loss = 0.32579
#     BATCH #649, D loss = 0.56245, G loss = 0.32589
#     BATCH #650, D loss = 0.42165, G loss = 0.32603
#     BATCH #651, D loss = 0.35640, G loss = 0.32631
#     BATCH #652, D loss = 0.37061, G loss = 0.32692
#     BATCH #653, D loss = 0.38663, G loss = 0.32672
#     BATCH #654, D loss = 0.40727, G loss = 0.32705
#     BATCH #655, D loss = 0.34613, G loss = 0.33646
#     BATCH #656, D loss = 0.43793, G loss = 0.34461
#     BATCH #657, D loss = 0.60785, G loss = 0.32698
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-632f0dcf577e> in <module>
#      70         g_optimizer.step()
#      71
# ---> 72         d_losses.append(d_loss.cpu().detach().numpy())
#      73         g_losses.append(g_loss.cpu().detach().numpy())
#      74
#
# KeyboardInterrupt:
