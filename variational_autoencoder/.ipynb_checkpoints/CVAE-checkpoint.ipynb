# %%
### First, build the model ###
import os
import numpy as np
import tensorflow as tf

from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from tensorflow.keras import optimizers, regularizers

class VAE(object):
    def __init__(self, input_shape=(28,28,1), latent_dim=2):
        self.input_shape = input_shape
        self.latent_dim = latent_dim
        
    def kl_divergence(self, y_true, y_pred):
        mean, logvar = tf.split(y_pred, num_or_size_splits=2, axis=1)
        
        kl_loss = -0.5 * K.sum(1 + logvar - 
                              K.square(mean) - 
                              K.exp(logvar), axis=-1)
        
        return kl_loss
        
    def build_decoder(self):
        inputs = Input(shape=(self.latent_dim,))
        d1 = Dense(7 * 7 * 16, activation='relu')(inputs)
        
        reshape = Reshape(target_shape=(7,7,16))(d1)
        
        ### Now dimension = 14 x 14 x 16 ###
        conv1 = Conv2DTranspose(16, activation='relu', kernel_size=3, strides=2, padding='same')(reshape)
        ### Now dimension = 28 x 28 x 8 ###
        conv2 = Conv2DTranspose(8, activation='relu', kernel_size=3, strides=2, padding='same')(conv1)
        output = Conv2DTranspose(1, kernel_size=3, strides=1, padding='same')(conv2)
        
        decoder = Model(inputs, output, name='Decoder')
        return decoder
    
    def build_encoder(self):
        inputs = Input(shape=self.input_shape)
        ### Now dimension = 14 x 14 x 8 ###
        conv1 = Conv2D(8, kernel_size=3, strides=(2,2), activation='relu')(inputs)
        ### Now dimension = 7 x 7 x 16 ###
        conv2 = Conv2D(16, kernel_size=3, strides=(2,2), activation='relu')(conv1)
        flatten = Flatten()(conv2)
        output = Dense(self.latent_dim + self.latent_dim)(flatten)
        
        encoder = Model(inputs, output, name='Encoder')
        return encoder
        
    def reparameterize(self, mean, logvar):
        eps = tf.random.normal(shape=(self.latent_dim,))
        return eps * tf.exp(logvar * 0.5) + mean
        
    def build(self):
        self.encoder = self.build_encoder()
        self.decoder = self.build_decoder()
        
        inputs = Input(shape=self.input_shape)
        encoded = self.encoder(inputs)
        
        ### Reparameterize and decode ###
        ### z = eps * sigma + mu ###
        mean, logvar = tf.split(encoded, num_or_size_splits=2, axis=1)
        z = self.reparameterize(mean, logvar)
        
        decoded = self.decoder(z)
        
        ### Rename the two tensors to assign losses ###
        encoded = Lambda(lambda x : x, name='encoded_output')(encoded)
        decoded = Lambda(lambda x : x, name='decoded_output')(decoded)
        model = Model(inputs, [decoded, encoded])
        
        return model
    
model = VAE().build()
print(model.summary())
# Out:
# Model: "functional_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            [(None, 28, 28, 1)]  0
# __________________________________________________________________________________________________
# Encoder (Functional)            (None, 4)            3556        input_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_split_1 (TensorFlow [(None, 2), (None, 2 0           Encoder[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_2 (TensorFlowOp [(None, 2)]          0           tf_op_layer_split_1[0][1]
# __________________________________________________________________________________________________
# tf_op_layer_Exp_1 (TensorFlowOp [(None, 2)]          0           tf_op_layer_Mul_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_3 (TensorFlowOp [(None, 2)]          0           tf_op_layer_Exp_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_1 (TensorFlow [(None, 2)]          0           tf_op_layer_Mul_3[0][0]
#                                                                  tf_op_layer_split_1[0][0]
# __________________________________________________________________________________________________
# Decoder (Functional)            (None, 28, 28, 1)    5905        tf_op_layer_AddV2_1[0][0]
# __________________________________________________________________________________________________
# decoded_output (Lambda)         (None, 28, 28, 1)    0           Decoder[0][0]
# __________________________________________________________________________________________________
# encoded_output (Lambda)         (None, 4)            0           Encoder[0][0]
# ==================================================================================================
# Total params: 9,461
# Trainable params: 9,461
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
### Then prepare the dataset ###
(X_train, _), (X_test, _) = tf.keras.datasets.mnist.load_data()

### Normalize the dataset to [-1, 1] range ###
def normalize_data(x):
    x = (x - 127.5) / 127.5
    return x
def denormalize_data(x):
    x = x * 127.5 + 127.5
    x = x.astype(np.uint8)
    return x

X_train = normalize_data(X_train)
X_test = normalize_data(X_test)

# %%
### Prepare training phases ###
import os
import numpy as np
import tensorflow as tf

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, CSVLogger

INPUT_SHAPE = (28,28,1)
LATENT_DIM = 2
BATCH_SIZE=64
EPOCHS=100
MODEL_CHECKPOINT = 'model_1.weights.hdf5'

vae = VAE(input_shape=INPUT_SHAPE, latent_dim=LATENT_DIM)
model = vae.build()
if(os.path.exists(MODEL_CHECKPOINT)):
    print('[*] Transfer learning from existing checkpoint ...')
    model.load_weights(MODEL_CHECKPOINT)

Y_train = {
    'decoded_output' : X_train,
    'encoded_output' : np.zeros((X_train.shape[0], LATENT_DIM * 2))
}

Y_test = {
    'decoded_output' : X_test,
    'encoded_output' : np.zeros((X_test.shape[0], LATENT_DIM * 2))
}

adam = Adam(lr=1e-3, amsgrad=True)
losses = {
    'decoded_output' : tf.keras.losses.mean_squared_error,
    'encoded_output' : vae.kl_divergence
}

def lr_decay(epochs, lr):
    decay_rate = 1 / EPOCHS
    init_lr = 1e-3 
    
    return init_lr * (1.0/(1.0 + decay_rate * epochs))

callbacks = [
    ModelCheckpoint(MODEL_CHECKPOINT, verbose=1, save_best_only=True),
    EarlyStopping(patience=15, verbose=1),
    CSVLogger('training.log.csv'),
    LearningRateScheduler(lr_decay, verbose=1)
]

model.compile(optimizer=adam, loss=losses)
model.fit(X_train, Y_train,
         callbacks=callbacks,
         validation_data=(X_test, Y_test),
         batch_size=BATCH_SIZE,
         epochs=EPOCHS)
# Out:
# [*] Transfer learning from existing checkpoint ...
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 1/100
# 921/938 [============================>.] - ETA: 0s - loss: 0.2980 - decoded_output_loss: 0.2946 - encoded_output_loss: 0.0034
# Epoch 00001: val_loss improved from inf to 0.24380, saving model to model_1.weights.hdf5
# 938/938 [==============================] - 2s 2ms/step - loss: 0.2970 - decoded_output_loss: 0.2936 - encoded_output_loss: 0.0034 - val_loss: 0.2438 - val_decoded_output_loss: 0.2416 - val_encoded_output_loss: 0.0022
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0009900990099009901.
# Epoch 2/100
# 936/938 [============================>.] - ETA: 0s - loss: 0.2370 - decoded_output_loss: 0.2350 - encoded_output_loss: 0.0020
# Epoch 00002: val_loss improved from 0.24380 to 0.23280, saving model to model_1.weights.hdf5
# 938/938 [==============================] - 2s 2ms/step - loss: 0.2370 - decoded_output_loss: 0.2350 - encoded_output_loss: 0.0020 - val_loss: 0.2328 - val_decoded_output_loss: 0.2309 - val_encoded_output_loss: 0.0019
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.000980392156862745.
# Epoch 3/100
# 921/938 [============================>.] - ETA: 0s - loss: 0.2300 - decoded_output_loss: 0.2282 - encoded_output_loss: 0.0019
# Epoch 00003: val_loss improved from 0.23280 to 0.22792, saving model to model_1.weights.hdf5
# 938/938 [==============================] - 2s 2ms/step - loss: 0.2299 - decoded_output_loss: 0.2281 - encoded_output_loss: 0.0019 - val_loss: 0.2279 - val_decoded_output_loss: 0.2262 - val_encoded_output_loss: 0.0017
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0009708737864077671.
# Epoch 4/100
# 922/938 [============================>.] - ETA: 0s - loss: 0.2258 - decoded_output_loss: 0.2240 - encoded_output_loss: 0.0018
# Epoch 00004: val_loss improved from 0.22792 to 0.22404, saving model to model_1.weights.hdf5
# 938/938 [==============================] - 2s 2ms/step - loss: 0.2258 - decoded_output_loss: 0.2240 - encoded_output_loss: 0.0018 - val_loss: 0.2240 - val_decoded_output_loss: 0.2222 - val_encoded_output_loss: 0.0018
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0009615384615384615.
# Epoch 5/100
# 914/938 [============================>.] - ETA: 0s - loss: 0.2228 - decoded_output_loss: 0.2210 - encoded_output_loss: 0.0018
# Epoch 00005: val_loss improved from 0.22404 to 0.22129, saving model to model_1.weights.hdf5
# 938/938 [==============================] - 2s 2ms/step - loss: 0.2228 - decoded_output_loss: 0.2210 - encoded_output_loss: 0.0018 - val_loss: 0.2213 - val_decoded_output_loss: 0.2195 - val_encoded_output_loss: 0.0018
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0009523809523809524.
# Epoch 6/100
# 918/938 [============================>.] - ETA: 0s - loss: 0.2209 - decoded_output_loss: 0.2192 - encoded_output_loss: 0.0017
# Epoch 00006: val_loss improved from 0.22129 to 0.22007, saving model to model_1.weights.hdf5
# 938/938 [==============================] - 2s 2ms/step - loss: 0.2208 - decoded_output_loss: 0.2191 - encoded_output_loss: 0.0017 - val_loss: 0.2201 - val_decoded_output_loss: 0.2184 - val_encoded_output_loss: 0.0016
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0009433962264150942.
# Epoch 7/100
# 930/938 [============================>.] - ETA: 0s - loss: 0.2193 - decoded_output_loss: 0.2176 - encoded_output_loss: 0.0017
# Epoch 00007: val_loss improved from 0.22007 to 0.21812, saving model to model_1.weights.hdf5
# 938/938 [==============================] - 2s 2ms/step - loss: 0.2193 - decoded_output_loss: 0.2176 - encoded_output_loss: 0.0017 - val_loss: 0.2181 - val_decoded_output_loss: 0.2165 - val_encoded_output_loss: 0.0017
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0009345794392523365.
# Epoch 8/100
# 937/938 [============================>.] - ETA: 0s - loss: 0.2181 - decoded_output_loss: 0.2164 - encoded_output_loss: 0.0017
# Epoch 00008: val_loss improved from 0.21812 to 0.21781, saving model to model_1.weights.hdf5
# 938/938 [==============================] - 2s 2ms/step - loss: 0.2181 - decoded_output_loss: 0.2164 - encoded_output_loss: 0.0017 - val_loss: 0.2178 - val_decoded_output_loss: 0.2162 - val_encoded_output_loss: 0.0016
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0009259259259259259.
# Epoch 9/100
# 912/938 [============================>.] - ETA: 0s - loss: 0.2171 - decoded_output_loss: 0.2154 - encoded_output_loss: 0.0016
# Epoch 00009: val_loss improved from 0.21781 to 0.21592, saving model to model_1.weights.hdf5
# 938/938 [==============================] - 2s 2ms/step - loss: 0.2170 - decoded_output_loss: 0.2153 - encoded_output_loss: 0.0016 - val_loss: 0.2159 - val_decoded_output_loss: 0.2143 - val_encoded_output_loss: 0.0017
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0009174311926605504.
# Epoch 10/100
# 938/938 [==============================] - ETA: 0s - loss: 0.2158 - decoded_output_loss: 0.2142 - encoded_output_loss: 0.0016
# Epoch 00010: val_loss improved from 0.21592 to 0.21453, saving model to model_1.weights.hdf5
# 938/938 [==============================] - 2s 2ms/step - loss: 0.2158 - decoded_output_loss: 0.2142 - encoded_output_loss: 0.0016 - val_loss: 0.2145 - val_decoded_output_loss: 0.2129 - val_encoded_output_loss: 0.0017
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0009090909090909091.
# Epoch 11/100
# 935/938 [============================>.] - ETA: 0s - loss: 0.2148 - decoded_output_loss: 0.2131 - encoded_output_loss: 0.0017
# Epoch 00011: val_loss improved from 0.21453 to 0.21413, saving model to model_1.weights.hdf5
# 938/938 [==============================] - 2s 2ms/step - loss: 0.2148 - decoded_output_loss: 0.2131 - encoded_output_loss: 0.0017 - val_loss: 0.2141 - val_decoded_output_loss: 0.2125 - val_encoded_output_loss: 0.0017
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0009009009009009008.
# Epoch 12/100
# 937/938 [============================>.] - ETA: 0s - loss: 0.2138 - decoded_output_loss: 0.2121 - encoded_output_loss: 0.0017
# Epoch 00012: val_loss improved from 0.21413 to 0.21313, saving model to model_1.weights.hdf5
# 938/938 [==============================] - 2s 2ms/step - loss: 0.2138 - decoded_output_loss: 0.2121 - encoded_output_loss: 0.0017 - val_loss: 0.2131 - val_decoded_output_loss: 0.2115 - val_encoded_output_loss: 0.0017
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0008928571428571428.
# Epoch 13/100
# 923/938 [============================>.] - ETA: 0s - loss: 0.2131 - decoded_output_loss: 0.2114 - encoded_output_loss: 0.0017
# Epoch 00013: val_loss improved from 0.21313 to 0.21257, saving model to model_1.weights.hdf5
# 938/938 [==============================] - 2s 2ms/step - loss: 0.2130 - decoded_output_loss: 0.2113 - encoded_output_loss: 0.0017 - val_loss: 0.2126 - val_decoded_output_loss: 0.2109 - val_encoded_output_loss: 0.0017
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0008849557522123895.
# Epoch 14/100
# 915/938 [============================>.] - ETA: 0s - loss: 0.2124 - decoded_output_loss: 0.2107 - encoded_output_loss: 0.0017
# Epoch 00014: val_loss improved from 0.21257 to 0.21143, saving model to model_1.weights.hdf5
# 938/938 [==============================] - 2s 2ms/step - loss: 0.2123 - decoded_output_loss: 0.2106 - encoded_output_loss: 0.0017 - val_loss: 0.2114 - val_decoded_output_loss: 0.2098 - val_encoded_output_loss: 0.0017
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0008771929824561404.
# Epoch 15/100
# 923/938 [============================>.] - ETA: 0s - loss: 0.2117 - decoded_output_loss: 0.2100 - encoded_output_loss: 0.0016
# Epoch 00015: val_loss improved from 0.21143 to 0.21082, saving model to model_1.weights.hdf5
# 938/938 [==============================] - 2s 2ms/step - loss: 0.2117 - decoded_output_loss: 0.2100 - encoded_output_loss: 0.0016 - val_loss: 0.2108 - val_decoded_output_loss: 0.2092 - val_encoded_output_loss: 0.0016
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0008695652173913045.
# Epoch 16/100
# 913/938 [============================>.] - ETA: 0s - loss: 0.2111 - decoded_output_loss: 0.2095 - encoded_output_loss: 0.0016
# Epoch 00016: val_loss improved from 0.21082 to 0.21024, saving model to model_1.weights.hdf5
# 938/938 [==============================] - 2s 2ms/step - loss: 0.2111 - decoded_output_loss: 0.2095 - encoded_output_loss: 0.0016 - val_loss: 0.2102 - val_decoded_output_loss: 0.2086 - val_encoded_output_loss: 0.0016
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0008620689655172415.
# Epoch 17/100
# 924/938 [============================>.] - ETA: 0s - loss: 0.2105 - decoded_output_loss: 0.2089 - encoded_output_loss: 0.0016
# Epoch 00017: val_loss improved from 0.21024 to 0.20939, saving model to model_1.weights.hdf5
# 938/938 [==============================] - 2s 2ms/step - loss: 0.2105 - decoded_output_loss: 0.2088 - encoded_output_loss: 0.0016 - val_loss: 0.2094 - val_decoded_output_loss: 0.2078 - val_encoded_output_loss: 0.0016
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0008547008547008548.
# Epoch 18/100
# 924/938 [============================>.] - ETA: 0s - loss: 0.2100 - decoded_output_loss: 0.2084 - encoded_output_loss: 0.0016
# Epoch 00018: val_loss improved from 0.20939 to 0.20903, saving model to model_1.weights.hdf5
# 938/938 [==============================] - 2s 2ms/step - loss: 0.2100 - decoded_output_loss: 0.2084 - encoded_output_loss: 0.0016 - val_loss: 0.2090 - val_decoded_output_loss: 0.2074 - val_encoded_output_loss: 0.0016
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0008474576271186442.
# Epoch 19/100
# 922/938 [============================>.] - ETA: 0s - loss: 0.2094 - decoded_output_loss: 0.2078 - encoded_output_loss: 0.0016
# Epoch 00019: val_loss improved from 0.20903 to 0.20857, saving model to model_1.weights.hdf5
# 938/938 [==============================] - 2s 2ms/step - loss: 0.2095 - decoded_output_loss: 0.2079 - encoded_output_loss: 0.0016 - val_loss: 0.2086 - val_decoded_output_loss: 0.2070 - val_encoded_output_loss: 0.0016
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.0008403361344537816.
# Epoch 20/100
# 910/938 [============================>.] - ETA: 0s - loss: 0.2091 - decoded_output_loss: 0.2075 - encoded_output_loss: 0.0016
# Epoch 00020: val_loss improved from 0.20857 to 0.20810, saving model to model_1.weights.hdf5
# 938/938 [==============================] - 2s 2ms/step - loss: 0.2091 - decoded_output_loss: 0.2075 - encoded_output_loss: 0.0016 - val_loss: 0.2081 - val_decoded_output_loss: 0.2065 - val_encoded_output_loss: 0.0016
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.0008333333333333334.
# Epoch 21/100
# 929/938 [============================>.] - ETA: 0s - loss: 0.2087 - decoded_output_loss: 0.2071 - encoded_output_loss: 0.0016
# Epoch 00021: val_loss improved from 0.20810 to 0.20755, saving model to model_1.weights.hdf5
# 938/938 [==============================] - 2s 2ms/step - loss: 0.2087 - decoded_output_loss: 0.2071 - encoded_output_loss: 0.0016 - val_loss: 0.2076 - val_decoded_output_loss: 0.2060 - val_encoded_output_loss: 0.0016
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.0008264462809917356.
# Epoch 22/100
# 936/938 [============================>.] - ETA: 0s - loss: 0.2083 - decoded_output_loss: 0.2067 - encoded_output_loss: 0.0016
# Epoch 00022: val_loss improved from 0.20755 to 0.20742, saving model to model_1.weights.hdf5
# 938/938 [==============================] - 2s 2ms/step - loss: 0.2083 - decoded_output_loss: 0.2067 - encoded_output_loss: 0.0016 - val_loss: 0.2074 - val_decoded_output_loss: 0.2058 - val_encoded_output_loss: 0.0017
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.000819672131147541.
# Epoch 23/100
# 912/938 [============================>.] - ETA: 0s - loss: 0.2079 - decoded_output_loss: 0.2064 - encoded_output_loss: 0.0016
# Epoch 00023: val_loss improved from 0.20742 to 0.20699, saving model to model_1.weights.hdf5
# 938/938 [==============================] - 2s 2ms/step - loss: 0.2079 - decoded_output_loss: 0.2064 - encoded_output_loss: 0.0016 - val_loss: 0.2070 - val_decoded_output_loss: 0.2054 - val_encoded_output_loss: 0.0016
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.0008130081300813008.
# Epoch 24/100
# 917/938 [============================>.] - ETA: 0s - loss: 0.2075 - decoded_output_loss: 0.2060 - encoded_output_loss: 0.0016
# Epoch 00024: val_loss improved from 0.20699 to 0.20677, saving model to model_1.weights.hdf5
# 938/938 [==============================] - 2s 2ms/step - loss: 0.2076 - decoded_output_loss: 0.2061 - encoded_output_loss: 0.0016 - val_loss: 0.2068 - val_decoded_output_loss: 0.2052 - val_encoded_output_loss: 0.0016
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.0008064516129032259.
# Epoch 25/100
# 912/938 [============================>.] - ETA: 0s - loss: 0.2074 - decoded_output_loss: 0.2058 - encoded_output_loss: 0.0016
# Epoch 00025: val_loss improved from 0.20677 to 0.20627, saving model to model_1.weights.hdf5
# 938/938 [==============================] - 2s 2ms/step - loss: 0.2073 - decoded_output_loss: 0.2057 - encoded_output_loss: 0.0016 - val_loss: 0.2063 - val_decoded_output_loss: 0.2048 - val_encoded_output_loss: 0.0015
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.0008.
# Epoch 26/100
# 919/938 [============================>.] - ETA: 0s - loss: 0.2070 - decoded_output_loss: 0.2054 - encoded_output_loss: 0.0015
# Epoch 00026: val_loss improved from 0.20627 to 0.20592, saving model to model_1.weights.hdf5
# 938/938 [==============================] - 2s 2ms/step - loss: 0.2070 - decoded_output_loss: 0.2054 - encoded_output_loss: 0.0015 - val_loss: 0.2059 - val_decoded_output_loss: 0.2044 - val_encoded_output_loss: 0.0015
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.0007936507936507937.
# Epoch 27/100
# 913/938 [============================>.] - ETA: 0s - loss: 0.2068 - decoded_output_loss: 0.2053 - encoded_output_loss: 0.0015
# Epoch 00027: val_loss improved from 0.20592 to 0.20583, saving model to model_1.weights.hdf5
# 938/938 [==============================] - 2s 2ms/step - loss: 0.2067 - decoded_output_loss: 0.2052 - encoded_output_loss: 0.0015 - val_loss: 0.2058 - val_decoded_output_loss: 0.2043 - val_encoded_output_loss: 0.0015
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.0007874015748031496.
# Epoch 28/100
# 921/938 [============================>.] - ETA: 0s - loss: 0.2065 - decoded_output_loss: 0.2050 - encoded_output_loss: 0.0015
# Epoch 00028: val_loss improved from 0.20583 to 0.20520, saving model to model_1.weights.hdf5
# 938/938 [==============================] - 2s 2ms/step - loss: 0.2065 - decoded_output_loss: 0.2049 - encoded_output_loss: 0.0015 - val_loss: 0.2052 - val_decoded_output_loss: 0.2036 - val_encoded_output_loss: 0.0016
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.00078125.
# Epoch 29/100
# 910/938 [============================>.] - ETA: 0s - loss: 0.2062 - decoded_output_loss: 0.2047 - encoded_output_loss: 0.0015
# Epoch 00029: val_loss did not improve from 0.20520
# 938/938 [==============================] - 2s 2ms/step - loss: 0.2062 - decoded_output_loss: 0.2046 - encoded_output_loss: 0.0015 - val_loss: 0.2055 - val_decoded_output_loss: 0.2040 - val_encoded_output_loss: 0.0015
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.0007751937984496124.
# Epoch 30/100
# 924/938 [============================>.] - ETA: 0s - loss: 0.2059 - decoded_output_loss: 0.2044 - encoded_output_loss: 0.0015

# %%
### Now test if the model is good ###
import tensorflow_probability as tfp
import matplotlib.pyplot as plt

def decode(model, z, apply_sigmoid=False):
    logits = model(z)
    if apply_sigmoid:
        probs = tf.sigmoid(logits)
        return probs
    return logits

def sample(model, eps=None):
    if eps is None:
        eps = tf.random.normal(shape=(100, self.latent_dim))
    return decode(model, eps, apply_sigmoid=True)

def plot_latent_images(model, n, digit_size=28):
    """Plots n x n digit images decoded from the latent space."""

    norm = tfp.distributions.Normal(0, 1)
    grid_x = norm.quantile(np.linspace(0.05, 0.95, n))
    grid_y = norm.quantile(np.linspace(0.05, 0.95, n))
    image_width = digit_size*n
    image_height = image_width
    image = np.zeros((image_height, image_width))

    for i, yi in enumerate(grid_x):
        for j, xi in enumerate(grid_y):
          z = np.array([[xi, yi]])
          x_decoded = sample(model,z)
          digit = tf.reshape(x_decoded[0], (digit_size, digit_size))
          image[i * digit_size: (i + 1) * digit_size,
                j * digit_size: (j + 1) * digit_size] = digit.numpy()
    
    image = denormalize_data(image)
    plt.figure(figsize=(10, 10))
    plt.imshow(image, cmap='Greys_r')
    plt.axis('Off')
    plt.show() 

vae = VAE().build()
if(os.path.exists(MODEL_CHECKPOINT)):
    print('[*] Found existing model checkpoint ... ')
    vae.load_weights(MODEL_CHECKPOINT)
decoder = vae.get_layer('Decoder')
plot_latent_images(decoder, 20)
# Out:
# [*] Found existing model checkpoint ...
